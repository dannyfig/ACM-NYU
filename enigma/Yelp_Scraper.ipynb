# %%
# Import required modules
import requests
from bs4 import BeautifulSoup
from pprint import pprint

# %%
# Define what we're looking for
what = "pizza"
where = "New York"

# Build parameter dictionary
params = {'find_desc': what,
          'find_loc': where}

# %%
# Define our bare-bones URL -- our page of origin
base_url = 'https://www.yelp.com/search?'

# For every Yelp parameter and user-provided value,
# append to our base_url
for param, value in params.items():
    base_url = "{0}{1}={2}&".format(base_url, param, value)
    
base_url
# Out:
# 'https://www.yelp.com/search?find_desc=pizza&find_loc=New York&'

# %%
# Retrieve web page using requests
request = requests.get(base_url)

# Parse the HTML returned by :request with BeautifulSoup
soup = BeautifulSoup(request.content, 'html.parser')

# Let's take a look
soup
# Out:
# <!DOCTYPE HTML>
#
# <!--[if lt IE 7 ]> <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie6 ie ltie9 ltie8 no-js" lang="en"> <![endif]-->
# <!--[if IE 7 ]>    <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie7 ie ltie9 ltie8 no-js" lang="en"> <![endif]-->
# <!--[if IE 8 ]>    <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie8 ie ltie9 no-js" lang="en"> <![endif]-->
# <!--[if IE 9 ]>    <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie9 ie no-js" lang="en"> <![endif]-->
# <!--[if (gt IE 9)|!(IE)]><!--> <html class="no-js" lang="en" xmlns:fb="http://www.facebook.com/2008/fbml"> <!--<![endif]-->
# <head>
# <script>
#             (function() {
#                 var main = null;
#
#                 var main=function(a){window.onerror=(function(){var c=function(e){return function(){var f;if(Array.prototype.toJSON){f=Array.prototype.toJSON;delete Array.prototype.toJSON}e.apply(this,arguments);if(f){Array.prototype.toJSON=f}}};var d=function(){for(var e=0;e<arguments.length;e++){if(arguments[e]!==undefined){return arguments[e]}}};var b=function(p,u,n){var v=window.event||{};var o=v.timeStamp||new Date().getTime();var f=d(window.location.href,null);var i=d(document.referrer,null);var s=null;u=d(v.filename,u,null);
# n=d(v.lineno,n,null);var l=function(B){try{var A;if(B&&B.nodeName&&B.nodeType&&B.nodeType===1){A=["<",B.nodeName.toLowerCase()];if(B.id){A.push(" id="+B.id)}if(B.className){A.push(" class="+B.className)}A.push(">");return A.join("")}}catch(C){return"(access denied)"}try{JSON.stringify(B);return B}catch(C){return"(cannot stringify)"}};var m=function(D){var B={};try{for(var A in D){B[A]=l(D[A])}}catch(C){return"Iteration on the message object failed: "+C}B.__toString=Object.prototype.toString.call(D);
# return B};var t=true;try{t=(p instanceof String||typeof p==="string")}catch(w){p="Couldn't determine the type of message received. Reason: "+w}var x=function(A,e){return A.slice(0,e.length)===e};if(t){var k=(x(p,"uncaught exception: CustomError: Error in protected function:")||x(p,"CustomError: Error in protected function:")||(u===""&&n===0&&p==="Script error."));if(k){return}}else{try{s=m(p)}catch(w){s="Message dump failed. Reason: "+w}p="Caught a non-string message."}var g=new XMLHttpRequest();
# var j=null;if(!!window.jQuery){j="jquery"}if(!!window.Prototype){j="prototype"}var z={errors:[{context:["Exception in un-protected function"],date:new Date(o).toGMTString(),load_secs:-1,message:p,extra:s,ready_state:document.readyState,lineNumber:n,fileName:u}],location:f,referrer:i,js_lib:j,yelpcode_template_version:a};var h=(document.getElementsByTagName("html")[0].getAttribute("webdriver")==="true");if(h){document.body.innerHTML="<h1>Javascript Error Detected</h1>";var r=document.createElement("div");
# r.setAttribute("id","pastebinTraceback");var q=document.createElement("code");var y;try{y=document.createTextNode("JS ERROR DETECTED\n"+window.JSON.stringify(z,null,2))}catch(w){y=document.createTextNode("JS ERROR DETECTED\nCannot JSON.stringify error -- Exception in un-protected function : "+p)}q.appendChild(y);r.appendChild(q);document.getElementsByTagName("body")[0].appendChild(r)}z=JSON.stringify(z);z=encodeURIComponent(z);g.open("POST","/client_errors",true);g.setRequestHeader("Content-Type","application/x-www-form-urlencoded");
# g.setRequestHeader("X-Requested-With","XMLHttpRequest");g.send("json="+z)};return c(b)})()};
#
#                 if (main === null) {
#                     throw 'invalid inline script, missing main declaration.';
#                 }
#                 main("43ddfe5ea0");
#             })();
#     </script>
# <script>            window.yPageStart = new Date().getTime();
# </script>
# <script>            var initialVisibilityState = document.webkitVisibilityState;
#
#                 yPerfTimings = [];
#
#                     ySitRepParams = {"site": "main", "uniqueRequestID": "f93faeaea0209e20", "isLoggedIn": false, "clientIP": "216.165.95.1", "servlet": "search", "zipkinTraceID": "f93faeaea0209e20", "datacenter": "iad1", "cfRayID": "2edd26da8f28078b-EWR", "serverStartTime": 1475799254213, "action": "search_html", "yuv_record": "FxhX9zd3MoSwyRIKJEhAesuKwEtEmF-Fn1rNFC9gQoGhsXdOV8Sh2lNN7HYs-1z8LuUp0P01NePVWaaMVWnZ5qdklQLAFpMk"};
#                     window.ySitRepParams['initialVisibilityState'] = initialVisibilityState;
#                     window.ySitRepParams['seoCohorts'] = null;
#
#
#             (function(H){H.className=H.className.replace(/\bno-js\b/,'js');})(document.documentElement);
# </script>
# <script>
#             (function() {
#                 var main = null;
#
#                 var main=function(){(function(d,e,j,h,f,c,b){d.GoogleAnalyticsObject=f;d[f]=d[f]||function(){(d[f].q=d[f].q||[]).push(arguments)},d[f].l=1*new Date();c=e.createElement(j),b=e.getElementsByTagName(j)[0];c.async=1;c.src=h;b.parentNode.insertBefore(c,b)})(window,document,"script","//www.google-analytics.com/analytics.js","ga")};
#
#                 if (main === null) {
#                     throw 'invalid inline script, missing main declaration.';
#                 }
#                 main();
#             })();
#     </script>
# <script>        (function (d, w) {
#             if (('ontouchstart' in w) || w.DocumentTouch && d instanceof w.DocumentTouch){
#                 var html = d.getElementsByTagName("html")[0];
#                 html.classList.add("touch");
#             }
#         }(document, window));
# </script>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="en" http-equiv="Content-Language"/>
# <meta content="Top Pizza in New York, NY - Prince Street Pizza, Lombardi's Pizza, Juliana's Pizza, NY Pizza Suprema, Patzeria Perfect Pizza, My Pie, Adrienne's Pizzabar, Grimaldi's, PN Wood Fired Pizza, Joe's Pizza" name="description"/>
# <meta content="Yelp,recommendation,San Francisco, bay area, local,business,review,friend,restaurant,dentist,doctor,salon,spa,shopping,store,share,community,massage,sushi,pizza,nails,New York,Los Angeles" name="keywords">
# <meta content="width=1020" name="viewport">
# <meta content="Yelp" name="application-name">
# <meta content="https://s3-media3.fl.yelpcdn.com/assets/2/www/img/7f906850f02b/ico/win8-tile.png" name="msapplication-TileImage">
# <meta content="#c41200" name="msapplication-TileColor">
# <meta content="https://www.yelp.com/" name="msapplication-starturl">
# <meta content="#c41200" name="msapplication-navbutton-color">
# <meta content="width=1024;height=768" name="msapplication-window">
# <meta content="Go to Yelp.com" name="msapplication-tooltip">
# <meta content="name=Find Reviews; action-uri=/; icon-uri=https://s3-media1.fl.yelpcdn.com/assets/2/www/img/a6bbc59c7458/ico/favicon-16x16.ico" name="msapplication-task">
# <meta content="name=Hot New Businesses; action-uri=/openings; icon-uri=https://s3-media1.fl.yelpcdn.com/assets/2/www/img/a6bbc59c7458/ico/favicon-16x16.ico" name="msapplication-task">
# <meta content="name=Yelp Deals; action-uri=/search?find_desc=deals; icon-uri=https://s3-media1.fl.yelpcdn.com/assets/2/www/img/a6bbc59c7458/ico/favicon-16x16.ico" name="msapplication-task">
# <meta content="app-id=284910350, app-argument=yelp:///search?location=New%20York&amp;terms=pizza&amp;utm_campaign=default&amp;utm_source=www" name="apple-itunes-app">
# <link href="android-app://com.yelp.android/yelp-app-indexing/search?find_desc=pizza&amp;find_loc=New%20York&amp;utm_campaign=search&amp;utm_medium=organic&amp;utm_source=google" rel="alternate"/>
# <link href="ios-app://284910350/yelp//search?location=New%20York&amp;terms=pizza&amp;utm_campaign=search&amp;utm_medium=organic&amp;utm_source=google" rel="alternate"/>
# <meta content="Yelp" property="al:ios:app_name">
# <meta content="284910350" property="al:ios:app_store_id">
# <meta content="https://www.yelp.com/search?find_desc=pizza&amp;find_loc=New+York%2C+NY&amp;utm_campaign=search&amp;utm_medium=organic&amp;utm_source=apple" property="al:ios:url">
# <link content="#c41200" href="//s3-media1.fl.yelpcdn.com/assets/srv0/yelp_styleguide/4374c8fd03d1/assets/img/logos/yelp_burst.svg" rel="mask-icon" sizes="any">
# <link href="//s3-media2.fl.yelpcdn.com/assets/srv0/yelp_styleguide/118ff475a341/assets/img/logos/favicon.ico" rel="shortcut icon">
# <link href="/opensearch" rel="search" title="Yelp" type="application/opensearchdescription+xml"/>
# <link href="https://www.yelp.com/search?find_desc=pizza&amp;find_loc=New+York%2C+NY" rel="canonical">
# <link href="https://en.yelp.be/search?find_desc=pizza&amp;find_loc=New+York%2C+NY" hreflang="en-be" rel="alternate">
# <link href="https://www.yelp.fr/search?find_desc=pizza&amp;find_loc=New+York%2C+NY" hreflang="fr-fr" rel="alternate">
# <link href="https://www.yelp.ca/search?find_desc=pizza&amp;find_loc=New+York%2C+NY" hreflang="en-ca" rel="alternate">
# <link href="https://fi.yelp.fi/search?find_desc=pizza&amp;find_loc=New+York%2C+NY" hreflang="fi-fi" rel="alternate">
# <link href="https://www.yelp.pt/search?find_desc=pizza&amp;find_loc=New+York%2C+NY" hreflang="pt-pt" rel="alternate">
# <link href="https://fr.yelp.ch/search?find_desc=pizza&amp;find_loc=New+York%2C+NY" hreflang="fr-ch" rel="alternate">
# <link href="https://www.yelp.it/search?find_desc=pizza&amp;find_loc=New+York%2C+NY" hreflang="it-it" rel="alternate">
# <link href="https://nl.yelp.be/search?find_desc=pizza&amp;find_loc=New+York%2C+NY" hreflang="nl-be" rel="alternate">
# <link href="https://nz.yelp.com/search?find_desc=pizza&amp;find_loc=New+York%2C+NY" hreflang="en-nz" rel="alternate">
# <link href="https://www.yelp.nl/search?find_desc=pizza&amp;find_loc=New+York%2C+NY" hreflang="nl-nl" rel="alternate">
# <link href="https://www.yelp.com/search?find_desc=pizza&amp;find_loc=New+York%2C+NY" hreflang="en-us" rel="alternate">
# <link href="https://www.yelp.com.sg/search?find_desc=pizza&amp;find_loc=New+York%2C+NY" hreflang="en-sg" rel="alternate">
# <link href="https://en.yelp.com.hk/search?find_desc=pizza&amp;find_loc=New+York%2C+NY" hreflang="en-hk" rel="alternate">
# <link href="https://www.yelp.com.au/search?find_desc=pizza&amp;find_loc=New+York%2C+NY" hreflang="en-au" rel="alternate">
# <link href="https://fr.yelp.be/search?find_desc=pizza&amp;find_loc=New+York%2C+NY" hreflang="fr-be" rel="alternate">
# <link href="https://de.yelp.ch/search?find_desc=pizza&amp;find_loc=New+York%2C+NY" hreflang="de-ch" rel="alternate">
# <link href="https://www.yelp.cl/search?find_desc=pizza&amp;find_loc=New+York%2C+NY" hreflang="es-cl" rel="alternate">
# <link href="https://www.yelp.co.jp/search?find_desc=pizza&amp;find_loc=New+York%2C+NY" hreflang="ja-jp" rel="alternate">
# <link href="https://www.yelp.at/search?find_desc=pizza&amp;find_loc=New+York%2C+NY" hreflang="de-at" rel="alternate">
# <link href="https://www.yelp.com.ar/search?find_desc=pizza&amp;find_loc=New+York%2C+NY" hreflang="es-ar" rel="alternate">
# <link href="https://www.yelp.es/search?find_desc=pizza&amp;find_loc=New+York%2C+NY" hreflang="es-es" rel="alternate">
# <link href="https://www.yelp.co.uk/search?find_desc=pizza&amp;find_loc=New+York%2C+NY" hreflang="en-gb" rel="alternate">
# <link href="https://en.yelp.com.ph/search?find_desc=pizza&amp;find_loc=New+York%2C+NY" hreflang="en-ph" rel="alternate">
# <link href="https://zh.yelp.com.hk/search?find_desc=pizza&amp;find_loc=New+York%2C+NY" hreflang="zh-hk" rel="alternate">
# <link href="https://fil.yelp.com.ph/search?find_desc=pizza&amp;find_loc=New+York%2C+NY" hreflang="fil-ph" rel="alternate">
# <link href="https://www.yelp.com.br/search?find_desc=pizza&amp;find_loc=New+York%2C+NY" hreflang="pt-br" rel="alternate">
# <link href="https://en.yelp.ch/search?find_desc=pizza&amp;find_loc=New+York%2C+NY" hreflang="en-ch" rel="alternate">
# <link href="https://www.yelp.dk/search?find_desc=pizza&amp;find_loc=New+York%2C+NY" hreflang="da-dk" rel="alternate">
# <link href="https://www.yelp.com.tw/search?find_desc=pizza&amp;find_loc=New+York%2C+NY" hreflang="zh-tw" rel="alternate">
# <link href="https://www.yelp.cz/search?find_desc=pizza&amp;find_loc=New+York%2C+NY" hreflang="cs-cz" rel="alternate">
# <link href="https://ms.yelp.my/search?find_desc=pizza&amp;find_loc=New+York%2C+NY" hreflang="ms-my" rel="alternate">
# <link href="https://en.yelp.my/search?find_desc=pizza&amp;find_loc=New+York%2C+NY" hreflang="en-my" rel="alternate">
# <link href="https://www.yelp.com.tr/search?find_desc=pizza&amp;find_loc=New+York%2C+NY" hreflang="tr-tr" rel="alternate">
# <link href="https://www.yelp.ie/search?find_desc=pizza&amp;find_loc=New+York%2C+NY" hreflang="en-ie" rel="alternate">
# <link href="https://www.yelp.de/search?find_desc=pizza&amp;find_loc=New+York%2C+NY" hreflang="de-de" rel="alternate">
# <link href="https://www.yelp.com.mx/search?find_desc=pizza&amp;find_loc=New+York%2C+NY" hreflang="es-mx" rel="alternate">
# <link href="https://sv.yelp.fi/search?find_desc=pizza&amp;find_loc=New+York%2C+NY" hreflang="sv-fi" rel="alternate">
# <link href="https://fr.yelp.ca/search?find_desc=pizza&amp;find_loc=New+York%2C+NY" hreflang="fr-ca" rel="alternate">
# <link href="https://www.yelp.se/search?find_desc=pizza&amp;find_loc=New+York%2C+NY" hreflang="sv-se" rel="alternate">
# <link href="https://it.yelp.ch/search?find_desc=pizza&amp;find_loc=New+York%2C+NY" hreflang="it-ch" rel="alternate">
# <link href="https://www.yelp.pl/search?find_desc=pizza&amp;find_loc=New+York%2C+NY" hreflang="pl-pl" rel="alternate">
# <link href="https://www.yelp.no/search?find_desc=pizza&amp;find_loc=New+York%2C+NY" hreflang="nb-no" rel="alternate">
# <link href="https://www.yelp.com/search?find_desc=pizza&amp;find_loc=New+York&amp;start=10" rel="next"/>
# <meta content="97534753161" property="fb:app_id">
# <meta content="Yelp" property="og:site_name">
# <meta content="website" property="og:type">
# <meta content="https://s3-media2.fl.yelpcdn.com/assets/srv0/seo_metadata/e98ed5a1460f/assets/img/logos/yelp_og_image.png" property="og:image">
# <meta content="576" property="og:image:height">
# <meta content="576" property="og:image:width">
# <title>Best Pizza in New York, NY</title>
# <!--[if (IE 9)|(lt IE 9) ]> <link rel="stylesheet" type="text/css" media="all" href="https://s3-media2.fl.yelpcdn.com/assets/2/www/css/0af1134484a2/www-pkg-main.css">
#             <link rel="stylesheet" type="text/css" media="all" href="https://s3-media4.fl.yelpcdn.com/assets/2/www/css/f5109ae0eaf9/www-pkg-more.css"> <![endif]-->
# <!--[if (gt IE 9)|!(IE)]><!--> <link href="https://s3-media4.fl.yelpcdn.com/assets/2/www/css/bd3334ba9d72/www-pkg.css" media="all" rel="stylesheet" type="text/css"> <!--<![endif]-->
# <link href="https://s3-media4.fl.yelpcdn.com/assets/2/www/css/fda6f6439bf3/new_search/search.css" media="all" rel="stylesheet" type="text/css">
# <script>
# </script>
# <link href="https://www.facebook.com/yelp" id="sitelink-profile-facebook" itemprop="sameAs">
# <link href="https://twitter.com/yelp" id="sitelink-profile-twitter" itemprop="sameAs">
# <link href="https://www.linkedin.com/company/31517" id="sitelink-profile-linkedin" itemprop="sameAs">
# <link href="https://plus.google.com/102333850216082449390/" id="sitelink-profile-gplus" itemprop="sameAs">
# <link href="https://instagram.com/yelp" id="sitelink-profile-instagram" itemprop="sameAs">
# <meta itemref="sitename sitelink  sitelink-profile-facebook sitelink-profile-twitter sitelink-profile-linkedin sitelink-profile-gplus sitelink-profile-instagram" itemscope="" itemtype="http://schema.org/WebSite">
# <meta content="Yelp" id="sitename" itemprop="name">
# <link href="https://www.yelp.com/" id="sitelink" itemprop="url">
# <script>
#             (function() {
#                 var main = null;
#
#                 var main=function(){!function(h,a,i,c,j,d,g){if(h.fbq){return}j=h.fbq=function(){j.callMethod?j.callMethod.apply(j,arguments):j.queue.push(arguments)};if(!h._fbq){h._fbq=j}j.push=j;j.loaded=!0;j.version="2.0";j.queue=[];d=a.createElement(i);d.async=!0;d.src=c;g=a.getElementsByTagName(i)[0];g.parentNode.insertBefore(d,g)}(window,document,"script","https://connect.facebook.net/en_US/fbevents.js");fbq("init","102029836881428");fbq("track","PageView")};
#
#                 if (main === null) {
#                     throw 'invalid inline script, missing main declaration.';
#                 }
#                 main();
#             })();
#     </script>
# <script defer="" src="/yla-qqqqsrf.js" type="text/javascript"></script><style type="text/css">#d__fFH{position:absolute;top:-5000px;left:-5000px}#d__fF{font-family:serif;font-size:200px;visibility:hidden}#ttrdrdydyycrzqxd{display:none!important}</style></link></meta></meta></link></link></link></link></link></link></link></meta></meta></meta></meta></meta></meta></link></link></link></link></link></link></link></link></link></link></link></link></link></link></link></link></link></link></link></link></link></link></link></link></link></link></link></link></link></link></link></link></link></link></link></link></link></link></link></link></link></link></link></link></link></meta></meta></meta></meta></meta></meta></meta></meta></meta></meta></meta></meta></meta></meta></meta></meta></head>
# <body class="country-us logged-out ytype jquery" id="yelp_main_body">
# <script>(function (d, w) {
#     var supportsSVG = (
#         !!d.createElementNS &&
#         !!d.createElementNS(
#             'http://www.w3.org/2000/svg',
#             'svg'
#         ).createSVGRect
#     );
#     var cdnPath = '//s3-media1.fl.yelpcdn.com/assets/srv0/svg_icons/07886a4e5506/assets/svg_sprite.js';
#     var head = d.getElementsByTagName('head')[0];
#     function fallback() {
#         var link = d.createElement('link');
#         link.rel = 'stylesheet';
#         link.href = '//s3-media4.fl.yelpcdn.com/assets/srv0/svg_icons/c6354a0abee9/assets/sprite.css';
#         head.appendChild(link);
#     }
#     if (!supportsSVG) {
#         fallback();
#         return;
#     }
#     if (!w.yelp) {
#         w.yelp = {};
#     }
#     w.yelp.__injectSvgSpritesheet = function (svg) {
#         document.body.insertAdjacentHTML('afterbegin', svg);
#         delete window.yelp.__injectSvgSpritesheet;
#     }
#     function onError() {
#         d.documentElement.className = [
#             d.documentElement.className,
#             'icon-svg-unavailable'
#         ].join(' ');
#         fallback();
#         return true;
#     }
#     var script = d.createElement('script');
#     script.async = true;
#     script.onerror = onError;
#     script.src = cdnPath + '?callback=window.yelp.__injectSvgSpritesheet';
#     head.appendChild(script);
# }(document, window));</script>
# <noscript>
# <link href="//s3-media4.fl.yelpcdn.com/assets/srv0/svg_icons/c6354a0abee9/assets/sprite.css" rel="stylesheet">
# </link></noscript>
# <div id="fb-root"></div>
# <div class="lang-en" id="wrap">
# <div>
# <ul class="offscreen">
# <li>
# <a href="#header_find_form" rel="nofollow">
#                         Skip to Search Form
#                     </a><div style="display: none;"><a href="ruqubvetfubbzvvcsyx.html" id="ttrdrdydyycrzqxd" rel="file">reebwxzaetuqufrdca</a></div>
# </li>
# <li>
# <a href="#header-nav" rel="nofollow">
#                         Skip to Navigation
#                     </a>
# </li>
# <li>
# <a href="#page-content" rel="nofollow">
#                         Skip to Page Content
#                     </a>
# </li>
# </ul>
# <div class="main-header main-content-wrap js-main-header webview-hidden">
# <div class="content-container">
# <div class="arrange arrange--18 main-header_arrange">
# <div class="arrange_unit main-header--full_arrange_unit">
# <div class="main-header_logo" id="logo">
# <a href="/">Yelp</a>
# </div>
# </div>
# <div class="arrange_unit arrange_unit--fill align-middle main-header--full_arrange_unit main-header_search-container">
# <div class="main-header_search responsive-hidden-medium-only">
# <form action="/search" class="main-search yform u-space-b0" id="header_find_form" method="get" role="search">
# <div class="arrange arrange--middle arrange--6 arrange--stack">
# <div class="arrange_unit main-search_search-field-arrange"> <div class="main-search_suggestions-field search-field-container find-decorator">
# <label class="main-search_pseudo-input pseudo-input">
# <span class="pseudo-input_text">Find</span>
# <span class="pseudo-input_field-holder">
# <input aria-autocomplete="list" autocomplete="off" class="main-search_field pseudo-input_field" id="find_desc" maxlength="64" name="find_desc" placeholder="tacos, cheap dinner, Max’s" tabindex="1" value="pizza">
# </input></span>
# </label>
# <div class="main-search_suggestions suggestions-list-container search-suggestions-list-container hidden">
# <ul aria-label="Search results" class="suggestions-list" role="listbox"></ul>
# </div>
# </div>
# </div>
# <div class="arrange_unit main-search_near-field-arrange main-search_search-field-arrange arrange_unit--stack-12"> <div class="main-search_suggestions-field search-field-container near-decorator">
# <label class="main-search_pseudo-input pseudo-input">
# <span class="pseudo-input_text">Near</span>
# <span class="main-search_field-holder pseudo-input_field-holder">
# <input aria-autocomplete="list" autocomplete="off" class="main-search_field pseudo-input_field" data-query="New York" id="dropperText_Mast" maxlength="80" name="find_loc" placeholder="address, neighborhood, city, state or zip" tabindex="2" value="New York">
# <input name="ns" type="hidden" value="1">
# </input></input></span>
# </label>
# <div class="main-search_suggestions suggestions-list-container location-suggestions-list-container hidden">
# <ul aria-label="Search results" class="suggestions-list" role="listbox"></ul>
# </div>
# </div>
# </div>
# <div class="arrange_unit main-search_actions arrange_unit--stack-12">
# <div class="arrange arrange--wrap arrange--6">
# <div class="arrange_unit hidden-non-responsive-inline-block responsive-visible-small-inline-block main-search_action">
# <a class="ybtn ybtn--primary main-header_button js-search-close main-search_close">Cancel</a>
# </div>
# <div class="arrange_unit main-search_action arrange_unit--stack-12">
# <button class="ybtn ybtn--primary main-search_submit main-header_button" id="header-search-submit" tabindex="3" title="Search" type="submit" value="submit">
# <span class="main-search_action-icon-wrap js-search-icon-wrap">
# <span aria-hidden="true" class="icon icon--18-search-small icon--size-18 icon--inverse icon--fallback-inverted" style="width: 18px; height: 18px;">
# <svg class="icon_svg">
# <use xlink:href="#18x18_search_small"></use>
# </svg>
# </span>
# <span class="u-offscreen">Search</span>
# </span>
# <div class="circle-spinner js-circle-spinner hidden">
# <div class="circle-spinner_segment container1">
# <div class="circle1"></div>
# <div class="circle2"></div>
# <div class="circle3"></div>
# <div class="circle4"></div>
# </div>
# <div class="circle-spinner_segment container2">
# <div class="circle1"></div>
# <div class="circle2"></div>
# <div class="circle3"></div>
# <div class="circle4"></div>
# </div>
# <div class="circle-spinner_segment container3">
# <div class="circle1"></div>
# <div class="circle2"></div>
# <div class="circle3"></div>
# <div class="circle4"></div>
# </div>
# </div>
# </button>
# </div>
# </div>
# </div>
# </div>
# </form>
# </div>
# <div class="main-header_nav nowrap responsive-hidden-medium">
# <ul class="header-nav" id="header-nav">
# <li class="header-nav_item" id="home-link">
# <a class="header-nav_link" href="/">
#                             Home
#                         </a>
# </li>
# <li class="header-nav_item" id="about-me">
# <a class="header-nav_link" href="/user_details">
#                             About Me
#                         </a>
# </li>
# <li class="header-nav_item" id="write-review">
# <a class="header-nav_link" href="/writeareview">
#                             Write a Review
#                         </a>
# </li>
# <li class="header-nav_item" id="find-friends">
# <a class="header-nav_link" href="/find_friends">
#                             Find Friends
#                         </a>
# </li>
# <li class="header-nav_item" id="messaging">
# <a class="header-nav_link" href="/mail">
#                             Messages
#                         </a>
# </li>
# <li class="header-nav_item" id="talk">
# <a class="header-nav_link" href="/talk">
#                             Talk
#                         </a>
# </li>
# <li class="header-nav_item" id="events">
# <a class="header-nav_link" href="/events">
#                             Events
#                         </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="arrange_unit main-header--full_arrange_unit">
# <div class="arrange arrange--6">
# <div class="arrange_unit nowrap">
# <div class="main-header_account webview-hidden">
# <ul class="header-nav">
# <li class="header-nav_item responsive-hidden-small">
# <a class="ybtn ybtn--primary main-header_button header-nav_button--sign-up js-sign-up-button" href="/signup" id="header-sign-up">Sign Up</a>
# </li>
# <li class="header-nav_item text-centered">
# <a class="header-nav_link header-nav_link--log-in js-log-in-button" href="https://www.yelp.com/login?return_url=%2Fsearch%3Ffind_desc%3Dpizza%26find_loc%3DNew%2BYork">
#                 Log In
#             </a>
# </li>
# </ul>
# <div class="user-account clearfix drop-menu-origin hidden-non-responsive-block responsive-visible-small-block" id="topbar-account-item">
# <a class="ybtn ybtn--primary drop-menu-link user-account_button" href="javascript:;" id="topbar-account-link">
# <span aria-hidden="true" class="icon icon--14-triangle-down icon--size-14 icon--inverse icon--fallback-inverted u-triangle-direction-down user-account_button-arrow responsive-visible-large-inline-block" style="width: 14px; height: 14px;">
# <svg class="icon_svg">
# <use xlink:href="#14x14_triangle_down"></use>
# </svg>
# </span>
# <span aria-hidden="true" class="icon icon--24-hamburger icon--size-24 icon--inverse icon--fallback-inverted drop-menu-link_open" style="width: 24px; height: 24px;">
# <svg class="icon_svg">
# <use xlink:href="#24x24_hamburger"></use>
# </svg>
# </span>
# <span aria-hidden="true" class="icon icon--24-close icon--size-24 icon--inverse icon--fallback-inverted drop-menu-link_close" style="width: 24px; height: 24px;">
# <svg class="icon_svg">
# <use xlink:href="#24x24_close"></use>
# </svg>
# </span>
# </a>
# <div class="drop-menu drop-menu-has-arrow" id="topbar-account-wrap">
# <div class="drop-menu-arrow responsive-hidden-small"></div>
# <div class="arrange arrange--6 arrange--equal drop-menu_auth-buttons">
# <div class="arrange_unit">
# <a class="ybtn ybtn-full" href="https://www.yelp.com/login?return_url=%2Fsearch%3Ffind_desc%3Dpizza%26find_loc%3DNew%2BYork">Login</a>
# </div>
# <div class="arrange_unit">
# <a class="ybtn ybtn--primary ybtn-full" href="/signup">Sign Up</a>
# </div>
# </div>
# <ul class="drop-menu-group--nav drop-menu-group">
# <li class="drop-down-menu-link">
# <div class="arrange arrange--middle arrange--6">
# <strong class="arrange_unit arrange_unit--fill">
# <a href="/user_details">
# <span aria-hidden="true" class="icon icon--24-profile icon--size-24 u-space-r1" style="width: 24px; height: 24px;">
# <svg class="icon_svg">
# <use xlink:href="#24x24_profile"></use>
# </svg>
# </span>About Me
#                     </a>
# </strong>
# <span class="arrange_unit">
# <span aria-hidden="true" class="icon icon--24-chevron-right icon--size-24 hidden-non-responsive-block responsive-visible-medium-block" style="width: 24px; height: 24px;">
# <svg class="icon_svg">
# <use xlink:href="#24x24_chevron_right"></use>
# </svg>
# </span>
# </span>
# </div>
# </li>
# <li class="drop-down-menu-link hidden-non-responsive-block responsive-visible-medium-block">
# <div class="arrange arrange--middle arrange--6">
# <strong class="arrange_unit arrange_unit--fill">
# <a href="/talk">
# <span aria-hidden="true" class="icon icon--24-speech icon--size-24 u-space-r1" style="width: 24px; height: 24px;">
# <svg class="icon_svg">
# <use xlink:href="#24x24_speech"></use>
# </svg>
# </span>Talk
#                     </a>
# </strong>
# <span class="arrange_unit">
# <span aria-hidden="true" class="icon icon--24-chevron-right icon--size-24 hidden-non-responsive-block responsive-visible-medium-block" style="width: 24px; height: 24px;">
# <svg class="icon_svg">
# <use xlink:href="#24x24_chevron_right"></use>
# </svg>
# </span>
# </span>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <script>
#             (function() {
#                 var main = null;
#
#                 var main=(function(){function a(b){window.yDFP.ABP={};window.yDFP.ABP.getPixelSource=function(c){return b+"?ch="+c+"&rn="+Math.random()*11};window.yDFP.ABP.detect=function(l){var g=false;var f=2;var i=false;var h=false;function k(n,m){if(f===0||m>400){n(f===0&&g)}else{setTimeout(function(){k(n,m*2)},m*2)}}function j(){if(f!==0){return}g=!i&&h}var e=function(){f-=1;j()};var d=new Image();d.onload=e;d.onerror=function(){i=true;e()};d.src=window.yDFP.ABP.getPixelSource(1);var c=new Image();c.onload=e;
# c.onerror=function(){h=true;e()};c.src=window.yDFP.ABP.getPixelSource(2);k(l,100)};window.yDFP.ABP.abpInstalledChannel="1382551876";window.yDFP.ABP.abpNotInstalledChannel="2859285073"}window.yDFP=window.yDFP||{};window.yDFP.initABPDetection=a;return window.yDFP.initABPDetection})();
#
#                 if (main === null) {
#                     throw 'invalid inline script, missing main declaration.';
#                 }
#                 main("/px.gif");
#             })();
#     </script>
# <div id="print-masthead">
# <img alt="Yelp" class="print-bkg-img" src="https://s3-media2.fl.yelpcdn.com/assets/2/www/img/b7e9d647188d/gfx/header_print.gif">
# </img></div>
# <span class="offscreen" id="page-content"> </span>
# <div class="main-content-wrap main-content-wrap--full">
# <div class="top-shelf top-shelf-grey">
# <div class="content-container">
# <div id="alert-container">
# </div>
# <div class="clearfix layout-block layout-full search-page-top">
# <div class="column column-alpha ">
# <div class="search-header clearfix">
# <h1>
#                 Best pizza <span class="query-location">in New York, NY</span>
# </h1>
# <span class="pagination-results-window">
#             Showing 1-10 of 11147
#         </span>
# <div class="search-category-browse-links">
# </div>
# </div>
# <div class="filter-panel">
# <div class="suggested-filters">
# <h4>Filters</h4>
# <ul class="suggested-filters_filter-list">
# <li>
# <ul class="suggested-filters_price-filters">
# <li>
# <label class="radio-check">
# <input name="price" type="checkbox" value="RestaurantsPriceRange2.1">
# <span class="filter-label show-tooltip">
#             $
#                 <span class="tooltip-wrapper">
# <span class="tooltip">Inexpensive</span>
# </span>
# </span>
# </input></label>
# </li>
# <li>
# <label class="radio-check">
# <input name="price" type="checkbox" value="RestaurantsPriceRange2.2">
# <span class="filter-label show-tooltip">
#             $$
#                 <span class="tooltip-wrapper">
# <span class="tooltip">Moderate</span>
# </span>
# </span>
# </input></label>
# </li>
# <li>
# <label class="radio-check">
# <input name="price" type="checkbox" value="RestaurantsPriceRange2.3">
# <span class="filter-label show-tooltip">
#             $$$
#                 <span class="tooltip-wrapper">
# <span class="tooltip">Pricey</span>
# </span>
# </span>
# </input></label>
# </li>
# <li>
# <label class="radio-check">
# <input name="price" type="checkbox" value="RestaurantsPriceRange2.4">
# <span class="filter-label show-tooltip">
#             $$$$
#                 <span class="tooltip-wrapper">
# <span class="tooltip">Ultra High-End</span>
# </span>
# </span>
# </input></label>
# </li>
# </ul>
# </li>
# <li> <label class="feature open-now radio-check">
# <input name="feature" type="checkbox" value="open_now">
# <span class="filter-label show-tooltip">
# <span aria-hidden="true" class="icon icon--18-clock icon--size-18 icon--neutral-gray" style="width: 18px; height: 18px;">
# <svg class="icon_svg">
# <use xlink:href="#18x18_clock"></use>
# </svg>
# </span>
#
#             Open Now     <span class="current-time"></span>
# <span class="tooltip-wrapper">
# <span class="tooltip">Find businesses that are open now</span>
# </span>
# </span>
# </input></label>
# </li>
# <li> <label class="feature radio-check">
# <input name="feature" type="checkbox" value="PlatformDelivery">
# <span class="filter-label show-tooltip">
# <span aria-hidden="true" class="icon icon--18-order icon--size-18" style="fill: #ca6d00; width: 18px; height: 18px;">
# <svg class="icon_svg">
# <use xlink:href="#18x18_order"></use>
# </svg>
# </span>
#
#             Order Pickup or Delivery
#
#                 <span class="tooltip-wrapper">
# <span class="tooltip">Find businesses that deliver to you</span>
# </span>
# </span>
# </input></label>
# </li>
# <li> <label class="feature radio-check">
# <input name="feature" type="checkbox" value="OnlineReservations">
# <span class="filter-label show-tooltip">
# <span aria-hidden="true" class="icon icon--18-reservation icon--size-18 icon--black" style="width: 18px; height: 18px;">
# <svg class="icon_svg">
# <use xlink:href="#18x18_reservation"></use>
# </svg>
# </span>
#
#             Make a Reservation
#
#                 <span class="tooltip-wrapper">
# <span class="tooltip">Find and book a table</span>
# </span>
# </span>
# </input></label>
# </li>
# <li> <label class="feature radio-check">
# <input name="feature" type="checkbox" value="ActiveDeal">
# <span class="filter-label show-tooltip">
# <span aria-hidden="true" class="icon icon--18-deal icon--size-18 icon--success" style="width: 18px; height: 18px;">
# <svg class="icon_svg">
# <use xlink:href="#18x18_deal"></use>
# </svg>
# </span>
#
#             Offering a Deal
#
#                 <span class="tooltip-wrapper">
# <span class="tooltip">Find businesses offering a deal</span>
# </span>
# </span>
# </input></label>
# </li>
# <li> <label class="radio-check">
# <span class="filter-label all-filters-toggle show-tooltip">
# <span aria-hidden="true" class="icon icon--18-filter icon--size-18 icon--currentColor" style="width: 18px; height: 18px;">
# <svg class="icon_svg">
# <use xlink:href="#18x18_filter"></use>
# </svg>
# </span> All Filters
#             <span class="tooltip-wrapper">
# <span class="tooltip" data-collapsed-text="Show more filters" data-expanded-text="Show fewer filters">Show more filters</span>
# </span>
# </span>
# </label>
# </li>
# </ul>
# </div>
# <div class="filter-panel_filters is-collapsed">
# <div class="filter-set sort-filters">
# <h4>Sort By</h4>
# <ul class="radio-list radio-list-links main">
# <li> <label>
# <input checked="checked" class="radio" name="sort" type="radio" value="best_match">
# <span class="radio-link">Best Match</span>
# </input></label>
# </li>
# <li> <label>
# <input class="radio" name="sort" type="radio" value="rating">
# <span class="radio-link">Highest Rated</span>
# </input></label>
# </li>
# <li> <label>
# <input class="radio" name="sort" type="radio" value="review_count">
# <span class="radio-link">Most Reviewed</span>
# </input></label>
# </li>
# </ul>
# </div>
# <div class="filter-set place-filters">
# <h4 class="place-filter-title">Neighborhoods</h4>
# <ul class="main">
# <li> <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Manhattan:Midtown_West">
# <span>Midtown West</span>
# </input></label>
# </li>
# <li> <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Manhattan:Midtown_East">
# <span>Midtown East</span>
# </input></label>
# </li>
# <li> <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Manhattan:Theater_District">
# <span>Theater District</span>
# </input></label>
# </li>
# <li> <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Manhattan:Upper_East_Side">
# <span>Upper East Side</span>
# </input></label>
# </li>
# </ul>
# <a class="more-link" href="javascript:;">More Neighborhoods</a>
# <ul class="more place-more">
# <div class="js-toggle-list-item toggle-list-item toggle-list-item--active">
# <h4 class="arrange arrange--middle toggle-list-link js-toggle-list-trigger u-space-b1">
# <span class="arrange_unit u-cursor-pointer">
# <span class="toggle-link-arrow-wrap u-inline-block">
# <span class="toggle-link-arrow" role="presentation"></span>
# </span>
# </span>
# <span class="arrange_unit arrange_unit--fill">
# <span class="u-pseudo-link u-decoration-none">Manhattan, NY</span>
# </span>
# </h4>
# <div class="js-toggle-list-content toggle-list-content">
# <div class="filter-group">
# <ul class="column">
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Manhattan:Alphabet_City">
# <span>Alphabet City</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Manhattan:Battery_Park">
# <span>Battery Park</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Manhattan:Central_Park">
# <span>Central Park</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Manhattan:Chelsea">
# <span>Chelsea</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Manhattan:Chinatown">
# <span>Chinatown</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Manhattan:Civic_Center">
# <span>Civic Center</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Manhattan:East_Harlem">
# <span>East Harlem</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Manhattan:East_Village">
# <span>East Village</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Manhattan:Financial_District">
# <span>Financial District</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Manhattan:Flatiron">
# <span>Flatiron</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Manhattan:Gramercy">
# <span>Gramercy</span>
# </input></label>
# </li>
# </ul>
# <ul class="column">
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Manhattan:Greenwich_Village">
# <span>Greenwich Village</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Manhattan:Harlem">
# <span>Harlem</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Manhattan:Hell's_Kitchen">
# <span>Hell's Kitchen</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Manhattan:Inwood">
# <span>Inwood</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Manhattan:Kips_Bay">
# <span>Kips Bay</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Manhattan:Koreatown">
# <span>Koreatown</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Manhattan:Little_Italy">
# <span>Little Italy</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Manhattan:Lower_East_Side">
# <span>Lower East Side</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Manhattan:Manhattan_Valley">
# <span>Manhattan Valley</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Manhattan:Marble_Hill">
# <span>Marble Hill</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Manhattan:Meatpacking_District">
# <span>Meatpacking District</span>
# </input></label>
# </li>
# </ul>
# <ul class="column">
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Manhattan:Midtown_East">
# <span>Midtown East</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Manhattan:Midtown_West">
# <span>Midtown West</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Manhattan:Morningside_Heights">
# <span>Morningside Heights</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Manhattan:Murray_Hill">
# <span>Murray Hill</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Manhattan:NoHo">
# <span>NoHo</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Manhattan:Nolita">
# <span>Nolita</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Manhattan:Roosevelt_Island">
# <span>Roosevelt Island</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Manhattan:SoHo">
# <span>SoHo</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Manhattan:South_Street_Seaport">
# <span>South Street Seaport</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Manhattan:South_Village">
# <span>South Village</span>
# </input></label>
# </li>
# </ul>
# <ul class="column">
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Manhattan:Stuyvesant_Town">
# <span>Stuyvesant Town</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Manhattan:Theater_District">
# <span>Theater District</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Manhattan:TriBeCa">
# <span>TriBeCa</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Manhattan:Two_Bridges">
# <span>Two Bridges</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Manhattan:Union_Square">
# <span>Union Square</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Manhattan:Upper_East_Side">
# <span>Upper East Side</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Manhattan:Upper_West_Side">
# <span>Upper West Side</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Manhattan:Washington_Heights">
# <span>Washington Heights</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Manhattan:West_Village">
# <span>West Village</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Manhattan:Yorkville">
# <span>Yorkville</span>
# </input></label>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="js-toggle-list-item toggle-list-item">
# <h4 class="arrange arrange--middle toggle-list-link js-toggle-list-trigger u-space-b1">
# <span class="arrange_unit u-cursor-pointer">
# <span class="toggle-link-arrow-wrap u-inline-block">
# <span class="toggle-link-arrow" role="presentation"></span>
# </span>
# </span>
# <span class="arrange_unit arrange_unit--fill">
# <span class="u-pseudo-link u-decoration-none">Brooklyn, NY</span>
# </span>
# </h4>
# <div class="js-toggle-list-content toggle-list-content">
# <div class="filter-group">
# <ul class="column">
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Brooklyn:Bath_Beach">
# <span>Bath Beach</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Brooklyn:Bay_Ridge">
# <span>Bay Ridge</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Brooklyn:Bedford_Stuyvesant">
# <span>Bedford Stuyvesant</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Brooklyn:Bensonhurst">
# <span>Bensonhurst</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Brooklyn:Bergen_Beach">
# <span>Bergen Beach</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Brooklyn:Boerum_Hill">
# <span>Boerum Hill</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Brooklyn:Borough_Park">
# <span>Borough Park</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Brooklyn:Brighton_Beach">
# <span>Brighton Beach</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Brooklyn:Brooklyn_Heights">
# <span>Brooklyn Heights</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Brooklyn:Brownsville">
# <span>Brownsville</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Brooklyn:Bushwick">
# <span>Bushwick</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Brooklyn:Canarsie">
# <span>Canarsie</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Brooklyn:Carroll_Gardens">
# <span>Carroll Gardens</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Brooklyn:City_Line">
# <span>City Line</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Brooklyn:Clinton_Hill">
# <span>Clinton Hill</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Brooklyn:Cobble_Hill">
# <span>Cobble Hill</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Brooklyn:Columbia_Street_Waterfront_District">
# <span>Columbia Street Waterfront District</span>
# </input></label>
# </li>
# </ul>
# <ul class="column">
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Brooklyn:Coney_Island">
# <span>Coney Island</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Brooklyn:Crown_Heights">
# <span>Crown Heights</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Brooklyn:Cypress_Hills">
# <span>Cypress Hills</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Brooklyn:DUMBO">
# <span>DUMBO</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Brooklyn:Ditmas_Park">
# <span>Ditmas Park</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Brooklyn:Downtown_Brooklyn">
# <span>Downtown Brooklyn</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Brooklyn:Dyker_Heights">
# <span>Dyker Heights</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Brooklyn:East_Flatbush">
# <span>East Flatbush</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Brooklyn:East_New_York">
# <span>East New York</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# <input name="place" type="checkbox" value="NY:New_York:Brooklyn:East_Williamsburg">
# <span>East Williamsburg</span>
# </input></label>
# </li>
# <li>
# <label class="place radio-check">
# ...
# if(d){window.googletag.pubads().setTargeting(d.key,d.value)}})}}window.yDFP=window.yDFP||{};window.yDFP.initQuantcast=a;return a})();
#
#                 if (main === null) {
#                     throw 'invalid inline script, missing main declaration.';
#                 }
#                 main("qntcst","p-M4yfUTCPeS3vn");
#             })();
#     </script>
# <noscript>
# <img alt="Quantcast" border="0" height="1" src="https://pixel.quantserve.com/pixel/p-M4yfUTCPeS3vn.gif" style="display: none;" width="1"/>
# </noscript>
# <script src="//ajax.googleapis.com/ajax/libs/jquery/1.8.3/jquery.min.js"></script><script>if(document.readyState === 'interactive') jQuery.ready();
#         yConfig = window.yConfig || {};
#         yConfig.vendorExternalURLs = yConfig.vendorExternalURLs || {};
#         </script><script src="https://s3-media1.fl.yelpcdn.com/assets/2/www/js/42464de454bb/assets/module_tmp_third_party-en_US.min.js"></script><script src="https://s3-media4.fl.yelpcdn.com/assets/2/www/js/0ad60c00beba/assets/module_core-en_US.min.js"></script><script>
#                 yConfig.vendorExternalURLs["plugin-detect"]=['https://s3-media4.fl.yelpcdn.com/assets/2/www/js/bfd62b330c7a/assets/vendor_external/plugin-detect-0.6.3.min.js']
#
#                 yConfig.vendorExternalURLs["fast-click"]=['https://s3-media1.fl.yelpcdn.com/assets/2/www/js/960df06ce458/assets/vendor_external/fastclick.min.js']
#                 yelp.www.init.initGoogleAnalytics({"domain": "yelp.com", "dimensions": {"www": {"i18n_search_title_experiment_all_markets_v2": [100, "no_cohort"], "promote_ads_to_non_advertiser_on_search_impression_shown": [147, "False"], "query_words_number": [52, "1"], "search_page_title_case": [43, "desc_city"], "viewport_tracking": [29, null], "distil": [53, 0], "internal_ip": [27, "False"], "traffic_search_on_page_content_v3": [44, "inactive_05_rpp_30_direct"], "category_mapping": [47, "pizza_990"], "account_level": [1, "anon"], "content_country": [15, "US"], "integration": [14, ""], "i18n_search_title_experiment_v2_es_fr": [142, "no_cohort"], "page_depth": [41, "0"], "hierarchy_breadcrumbs": [82, "False"], "full_url": [34, "/search?find_desc=pizza\u0026find_loc=New+York"], "distil_js_enabled": [138, true], "querylm_match": [67, "pizza_990"], "has_canonical": [36, "True"], "business_id": [141, ""], "search_snippets_seo_experiment": [17, "inactive_03_bigger"], "search_city": [49, "New York"], "facets_on_search_page": [123, 0], "q2c_match": [68, "sandwiches_1039"], "exact_name_match": [50, "False"], "is_indexable": [42, "True"], "referrer": [64, "none"], "results_on_page": [51, "10"], "mtb_weekly_growth_1": [85, "mtb_composer_enhancements-status_quo"], "is_biz_user": [129, "False"], "traffic_search_facets_experiment": [105, ["inactive_facets_only_2"]], "search_accuracy": [48, "4"]}, "global": {"distil_js_enabled": [13, true], "exact_name_match": [14, "False"], "querylm_match": [26, "pizza_990"], "distil": [12, 0], "referrer": [28, "none"], "search_page_title_case": [32, "desc_city"], "content_country": [11, "US"], "query_words_number": [25, "1"], "integration": [17, ""], "search_city": [31, "New York"], "internal_ip": [18, "False"], "q2c_match": [24, "sandwiches_1039"], "is_indexable": [19, "True"], "category_mapping": [9, "pizza_990"], "search_accuracy": [30, "4"], "results_on_page": [29, "10"], "has_canonical": [16, "True"], "full_url": [15, "/search?find_desc=pizza\u0026find_loc=New+York"], "account_level": [1, "anon"]}}, "enable_high_volume_events": false, "trackers": {"www": "UA-30501-24", "global": "UA-30501-1"}, "js_dimensions": {"www": {"platform_order_type": [127, null], "js_pixel_ratio": [16, null], "js_vertical_search_type": [39, null]}, "global": {}}, "clientID": "73E0133F20191324", "metrics": {"www": {"mtb-reply-rate-shown": [4, null], "mtb-response-time-shown": [1, null]}, "global": {}}}, {"www": {"www_search_snippets_in_sync_with_ads": [112, "status_quo_8"], "ytp_eat24_yelp_style_to_iframe": [136, "status_quo"], "txn_growth.www.recovery_experience_results_experiment": [124, "status_quo"], "txn_growth_filter_act_like_auto_enable": [54, "status_quo"], "auto_enable_pickup": [26, "disabled"], "transaction_growth_featured_people_also_viewed": [77, "status_quo"], "pinterest_share_on_biz_photo": [80, "status_quo"], "www_biz_details_claim_status": [109, "link_only"], "www_biz_details_claim_status_v2": [152, "confirmed_biz_badge"], "photos_new_js_flow": [25, "enabled"], "txn_growth_search_answers_reservations": [45, "status_quo"], "next_biz_card_on_search": [97, "status_quo"], "pagelet_mode_www_biz_details": [24, "allow_async"], "txn_growth.www.show_coachmark_on_food_widget": [139, "status_quo"], "txn_growth.www.delivery_attributes_biz_page": [84, "status_quo"], "www_fixed_header_v2": [13, "status_quo"], "ytp_order_confirmation_page": [143, "enabled"], "auto_enable_with_separated_search": [32, "enabled"], "login_use_new_flow": [78, "enabled"], "txn_growth.www.reservation_button_color_experiment": [104, "status_quo"], "styleguided_event_browse": [106, "enabled"], "embeddable_reviews": [98, "enabled"], "dead_end_separated_search": [18, "enabled"], "txn_growth_show_widget_on_non_platform_biz": [76, "status_quo"], "txn_growth_search_answers_food": [40, "status_quo"], "txn_growth.platform_wilson_score_exponent_v2": [63, "exponent_is_strong"], "www_signup_redesign": [92, "status_quo"], "styleguided_event_landing": [107, "en ...
# yelp.www.init.initSearchSuggest("#find_desc", ".find-decorator", "#dropperText_Mast", true, false);
# yelp.www.init.initAccountMenu("#topbar-account-item");
# yelp.common.init.adVisibilityTracker("/ad_visibility", "dc47b736f4b7a70426b2e002037ad270126a20079bc5817a846543efa1b6b8fc");
# yelp.www.init.initTimeOnPageAnalytics();
# yelp.init.initDelegatedDropdowns();
# yelp.init.attachGhostHovercard("qype", "    \u003cdiv id=\"qype-ghost-user-hovercard\"\u003e\n        \u003cdiv class=\"whatsthis-hovercard\"\u003e\n            \u003ch3\u003eWhat's This?\u003c/h3\u003e\n            \u003cp\u003eThis user has arrived from Qype, a company acquired by Yelp in 2012. We have integrated the two sites to bring you one great local experience.\u003c/p\u003e\n        \u003c/div\u003e\n    \u003c/div\u003e\n");
# yelp.init.attachGhostHovercard("rk", "    \u003cdiv id=\"rk-ghost-user-hovercard\"\u003e\n        \u003cdiv class=\"whatsthis-hovercard\"\u003e\n            \u003ch3\u003eWhat's This?\u003c/h3\u003e\n            \u003cp\u003eThis user has arrived from Restaurant-Kritik.de, a company acquired by Yelp in 2014. We have integrated the two sites to bring you one great local experience.\u003c/p\u003e\n        \u003c/div\u003e\n    \u003c/div\u003e\n");
# yelp.init.attachGhostHovercard("cityvox", "    \u003cdiv id=\"cityvox-ghost-user-hovercard\"\u003e\n        \u003cdiv class=\"whatsthis-hovercard\"\u003e\n            \u003ch3\u003eWhat's This?\u003c/h3\u003e\n            \u003cp\u003eThis user has arrived from Cityvox, a company acquired by Yelp in 2014. We have integrated the two sites to bring you one great local experience.\u003c/p\u003e\n        \u003c/div\u003e\n    \u003c/div\u003e\n");
# yelp.www.init.initAsyncImageLoader();
# yelp.pages.init();
# yelp.www.init.facebook("97534753161", "//connect.facebook.net/en_US/sdk.js", "v2.3", "v2", ["email", "user_birthday"], ["publish_actions"], ["publish_actions", "user_friends"]);
# yelp_display_ads.init.quantcast();
# </script><script src="https://s3-media1.fl.yelpcdn.com/assets/2/www/js/42f966d8cc58/assets/module_search-en_US.min.js"></script><script>yelp.www.init.search.Controller({"overlay_width": null, "service_areas": [], "library": "google", "zoom_control_position": "top_left", "market": null, "center": {"latitude": 40.71377274449591, "longitude": -74.00665283203125}, "zoom": 10, "markers": {"1": {"url": "/biz/prince-street-pizza-new-york-2", "location": {"latitude": 40.7229087705545, "longitude": -73.9944863319397}, "key": 1, "hovercard_id": "fwtJ6iALgwm4NBbYiM_2ew", "resource_type": "business", "icon": {"anchor_offset": [12, 32], "active_uri": "https://media2.fl.yelpcdn.com/mapmarkers/yelp_map_range/20160801/1/10.png", "regular_uri": "https://media2.fl.yelpcdn.com/mapmarkers/yelp_map_range/20160801/1/10.png", "scaled_size": [48, 320], "active_origin": [24, 0], "regular_origin": [0, 0], "size": [24, 32]}}, "2": {"url": "/biz/lombardis-pizza-new-york", "location": {"latitude": 40.7215332, "longitude": -73.9956344}, "key": 2, "hovercard_id": "NI3thL0eQspXisRqGO8Hlw", "resource_type": "business", "icon": {"anchor_offset": [12, 32], "active_uri": "https://media2.fl.yelpcdn.com/mapmarkers/yelp_map_range/20160801/1/10.png", "regular_uri": "https://media2.fl.yelpcdn.com/mapmarkers/yelp_map_range/20160801/1/10.png", "scaled_size": [48, 320], "active_origin": [24, 32], "regular_origin": [0, 32], "size": [24, 32]}}, "3": {"url": "/biz/julianas-pizza-brooklyn-5", "location": {"latitude": 40.7025851365081, "longitude": -73.9935619790676}, "key": 3, "hovercard_id": "35vhJmMTZyntSL3LHb0Ebw", "resource_type": "business", "icon": {"anchor_offset": [12, 32], "active_uri": "https://media2.fl.yelpcdn.com/mapmarkers/yelp_map_range/20160801/1/10.png", "regular_uri": "https://media2.fl.yelpcdn.com/mapmarkers/yelp_map_range/20160801/1/10.png", "scaled_size": [48, 320], "active_origin": [24, 64], "regular_origin": [0, 64], "size": [24, 32]}}, "4": {"url": "/biz/ny-pizza-suprema-new-york", "location": {"latitude": 40.750205, "longitude": -73.995321}, "key": 4, "hovercard_id": "sl6sO2oOuM1gZ77dYgVCfQ", "resource_type": "business", "icon": {"anchor_offset": [12, 32], "active_uri": "https://media2.fl.yelpcdn.com/mapmarkers/yelp_map_range/20160801/1/10.png", "regular_uri": "https://media2.fl.yelpcdn.com/mapmarkers/yelp_map_range/20160801/1/10.png", "scaled_size": [48, 320], "active_origin": [24, 96], "regular_origin": [0, 96], "size": [24, 32]}}, "5": {"url": "/biz/patzeria-perfect-pizza-new-york", "location": {"latitude": 40.7596523033459, "longitude": -73.9873650623614}, "key": 5, "hovercard_id": "_TsOMVWffTG3D83ElEt52w", "resource_type": "business", "icon": {"anchor_offset": [12, 32], "active_uri": "https://media2.fl.yelpcdn.com/mapmarkers/yelp_map_range/20160801/1/10.png", "regular_uri": "https://media2.fl.yelpcdn.com/mapmarkers/yelp_map_range/20160801/1/10.png", "scaled_size": [48, 320], "active_origin": [24, 128], "regular_origin": [0, 128], "size": [24, 32]}}, "6": {"url": "/biz/my-pie-new-york", "location": {"latitude": 40.7608512, "longitude": -73.9694809}, "key": 6, "hovercard_id": "7RBgpPSAgn3Bw7-w2_4gHA", "resource_type": "business", "icon": {"anchor_offset": [12, 32], "active_uri": "https://media2.fl.yelpcdn.com/mapmarkers/yelp_map_range/20160801/1/10.png", "regular_uri": "https://media2.fl.yelpcdn.com/mapmarkers/yelp_map_range/20160801/1/10.png", "scaled_size": [48, 320], "active_origin": [24, 160], "regular_origin": [0, 160], "size": [24, 32]}}, "7": {"url": "/biz/adriennes-pizzabar-new-york", "location": {"latitude": 40.7043362, "longitude": -74.0101733}, "key": 7, "hovercard_id": "TvlovZ-l1zPoJmm__Cszww", "resource_type": "business", "icon": {"anchor_offset": [12, 32], "active_uri": "https://media2.fl.yelpcdn.com/mapmarkers/yelp_map_range/20160801/1/10.png", "regular_uri": "https://media2.fl.yelpcdn.com/mapmarkers/yelp_map_range/20160801/1/10.png", "scaled_size": [48, 320], "active_origin": [24, 192], "regular_origin": [0, 192], "size": [24, 32] ...
# </script><script src="//sb.scorecardresearch.com/beacon.js"></script><script>
#                 if (window.COMSCORE && window.COMSCORE['beacon']) {
#                     window.COMSCORE['beacon']({'c15': '', 'c3': '', 'c2': 7130511, 'c1': 2, 'c6': '', 'c5': '', 'c4': ''});
#                 }
#                 </script>
# <script>
#             (function() {
#                 var main = null;
#
#                 var main=function(){if(["iPhone","iPod","iPad"].indexOf(navigator.platform)===-1||!window.requestAnimationFrame){return}window.bannerDetectionInitialScroll=window.bannerDetectionInitialScroll||window.scrollY||-100;requestAnimationFrame(function(){window.scrollTo(0,-100);requestAnimationFrame(function(){window.scrollBy(0,1);requestAnimationFrame(function(){window.userHasYelpApp=!window.scrollY;window.scrollTo(0,window.bannerDetectionInitialScroll)})})})};
#
#                 if (main === null) {
#                     throw 'invalid inline script, missing main declaration.';
#                 }
#                 main();
#             })();
#     </script>
# <script>
#             (function() {
#                 var main = null;
#
#                 var main=function loadSpice(g){var j=0;var k=1;var h=2;var e="0";var i="1";var l=function(){if(document.querySelector){return document.querySelector(".delay-spice")}var m=document.getElementsByTagName("div");var p=m.length;var o=new RegExp("(^|\\s)delay-spice(\\s|$)");for(var n=0;n<p;++n){if(o.test(m[n].className)){return m[n]}}return null};function d(){return(window._gaUserPrefs&&window._gaUserPrefs["ioo"]&&typeof(window._gaUserPrefs["ioo"])==="function"&&window._gaUserPrefs["ioo"]()===true||false)?"1":"0"
# }function f(o,n){var p;if(n===j){p=["/ad_sp","ice?","r=",g]}else{p=["/sp","ice?","r=",g];if(n===h){p.push("&log_ad_spice=1")}}p.push("&pagevis="+o);p.push("&gablock="+d());var m=new Image();m.src=p.join("")}function b(m){if(l()){f(m,k);c(m)}else{f(m,h)}}function c(m){if(l()){window.setTimeout(function(){c(m)},500)}else{f(m,j)}}if(!document.webkitHidden){b(e)}else{var a=false;document.addEventListener("webkitvisibilitychange",function(){if(document.webkitHidden||a){return}a=true;b(i)})}};
#
#                 if (main === null) {
#                     throw 'invalid inline script, missing main declaration.';
#                 }
#                 main("f93faeaea0209e20");
#             })();
#     </script>
# <script>
#             (function() {
#                 var main = null;
#
#                 var main=function(){var a=new Image(1,1);a.onerror=a.onload=function(){a.onerror=a.onload=null};a.src=["//secure-us.imrworldwide.com/cgi-bin/m?ci=us-804377h&cg=0&cc=1&si=",escape(window.location.href),"&rp=",escape(document.referrer),"&ts=compact&rnd=",(new Date()).getTime()].join("")};
#
#                 if (main === null) {
#                     throw 'invalid inline script, missing main declaration.';
#                 }
#                 main();
#             })();
#     </script>
# <noscript>
# <img alt="" height="1" src="//secure-us.imrworldwide.com/cgi-bin/m?ci=us-804377h&amp;cg=0&amp;cc=1&amp;ts=noscript" width="1">
# </img></noscript>
# <script>                yConfig.csrf = {"SitRep": "6f4389e9f9e28102f04c320e534489d0e3a325bfd18f0346eb6fd8511640c905", "FacebookTokenRefresh": "8a6a433426aa0af1a3055df90e5f1fa7c074c0f8d5dc01d9eac615eeec6c66de"};
# </script>
# <div id="ttdUniversalPixelTag290e816a69e9439f960a9588bc2ffb54" style="display:none">
# <script src="https://js.adsrvr.org/up_loader.1.1.0.js" type="text/javascript"></script>
# <script>
#             (function() {
#                 var main = null;
#
#                 var main=function(){(function(b){if(typeof TTDUniversalPixelApi==="function"){var a=new TTDUniversalPixelApi();a.init("igcouad",["mvh4ai1"],"https://insight.adsrvr.org/track/up","ttdUniversalPixelTag290e816a69e9439f960a9588bc2ffb54")}})(this)};
#
#                 if (main === null) {
#                     throw 'invalid inline script, missing main declaration.';
#                 }
#                 main();
#             })();
#     </script>
# </div>
# <noscript>
# <img height="1" src="https://www.facebook.com/tr?id=102029836881428&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
# </noscript>
# </body>
# </html>

# %%
returned_text = {}

i = 1
for record in soup.find_all('li', 'regular-search-result'):
    returned_text[i] = record.text
    i = i + 1
    
returned_text
# Out:
# {1: "\n\n\n\n\n\n\n\n\n\n\n\n\n\n1.         Prince Street Pizza\n\n\n\n\n\n\n\n\n\n            800 reviews\n    \n\n\n\n$\n\n\nPizza\n\n\n\n\n\n\n\n\n\n\n\n                    On the menu: Greene Machine Pizza\n\n\n\n\n\n\n\n\n            Nolita        \n\n            27 Prince StNew York, NY 10012\n        \nPhone number\n\n        (212) 966-4100\n    \n\n\n\n\n\n\n\n\n\n\n\n\n                        I'm a big pizza fan and I just love to travel for Pizza. \xa0But this pizza changed all that. \xa0 Prince street pizza is hands down my favorite pizza in NY. I pick this over Joe's. \xa0 I…\n                        read more\n\n\n\n\n",
#  2: "\n\n\n\n\n\n\n\n\n\n\n\n\n\n2.         Lombardi’s Pizza\n\n\n\n\n\n\n\n\n\n            4915 reviews\n    \n\n\n\n$$\n\n\nPizza\n\n\n\n\n\n\n\n\n\n\n\n                    On the menu: White Pizza\n\n\n\n\n\n\n\n\n            Nolita        \n\n            32 Spring StNew York, NY 10012\n        \nPhone number\n\n        (212) 941-7994\n    \n\n\n\n\n\n\n\n\n\n\n\n\n                        This place is cool. There was a little bit of wait, but it wasn't too bad. But cash only?? That's unheard of! The pizzas here are expensive, so being a cash only place is not a good…\n                        read more\n\n\n\n\n",
#  3: '\n\n\n\n\n\n\n\n\n\n\n\n\n\n3.         Juliana’s Pizza\n\n\n\n\n\n\n\n\n\n            1107 reviews\n    \n\n\n\n$$\n\n\nPizza\n\n\n\n\n\n\n\n\n\n\n\n                    On the menu: Margherita pizza\n\n\n\n\n\n\n\n\n            DUMBO        \n\n            19 Old Fulton StBrooklyn, NY 11201\n        \nPhone number\n\n        (718) 596-6700\n    \n\n\n\n\n\n\n\n\n\n\n\n\n                        Learned about this place from our Tour Guide and boy what a great decision it was to come here, even though it was a bit of a wait. \xa0They are spinning the dough in the front of the…\n                        read more\n\n\n\n\n',
#  4: '\n\n\n\n\n\n\n\n\n\n\n\n\n\n4.         NY Pizza Suprema\n\n\n\n\n\n\n\n\n\n            1099 reviews\n    \n\n\n\n$\n\n\nPizza\n\n\n\n\n\n\n\n\n\n            Chelsea, Midtown West        \n\n            413 8th AveNew York, NY 10001\n        \nPhone number\n\n        (212) 594-8939\n    \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n            This restaurant does food delivery\n        \n\n\nStart Order\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n                        So glad I found this place. Definitely one of my favorite pizza joints in NY they do justice to NYC pizza. \xa0a little on the pricier side, but the taste is amazing. the crust is thin…\n                        read more\n\n\n\n\n',
#  5: '\n\n\n\n\n\n\n\n\n\n\n\n\n\n5.         Patzeria Perfect Pizza\n\n\n\n\n\n\n\n\n\n            1043 reviews\n    \n\n\n\n$\n\n\nPizza,\n                    Diners\n\n\n\n\n\n\n\n\n\n            Theater District, Midtown West        \n\n            231 W 46th StNew York, NY 10036\n        \nPhone number\n\n        (212) 575-7646\n    \n\n\n\n\n\n\n\n\n\n\n\n\n                        Came on a whim because it was close to our hotel and we were HANGRY! .... Oh boy, did we luck out! Pizza was amazing! Ordered sausage and pepperoni, lasagna pizza, and ricotta,…\n                        read more\n\n\n\n\n',
#  6: "\n\n\n\n\n\n\n\n\n\n\n\n\n\n6.         My Pie\n\n\n\n\n\n\n\n\n\n            312 reviews\n    \n\n\n\n$\n\n\nItalian,\n                    Pizza\n\n\n\n\n\n\n\n\n\n            Midtown East        \n\n            696 Lexington AveNew York, NY 10022\n        \nPhone number\n\n        (212) 317-1850\n    \n\n\n\n\n\n\n\n\n\n\n\n\n                        Thank God for my girlfriend's Gluten Allergy. I never thought I would say that, but we tried this place out after seeing on Yelp they offered GF Pizza. \xa0 I stuck to regular pizza,…\n                        read more\n\n\n\n\n",
#  7: '\n\n\n\n\n\n\n\n\n\n\n\n\n\n7.         Adrienne’s Pizzabar\n\n\n\n\n\n\n\n\n\n            1069 reviews\n    \n\n\n\n$$\n\n\nPizza,\n                    Italian\n\n\n\n\n\n\n\n\n\n            Financial District        \n\n            54 Stone StNew York, NY 10004\n        \nPhone number\n\n        (212) 248-3838\n    \n\n\n\n\n\n\n\n\n\n\n\n\n                        Consistently good pizza in the Financial District (FiDi). \xa0This place brings back delicious memories. \xa0I moved to NYC in June 2009 and scored an incredible deal on a Wall Street…\n                        read more\n\n\n\n\n',
#  8: '\n\n\n\n\n\n\n\n\n\n\n\n\n\n8.         Grimaldi’s\n\n\n\n\n\n\n\n\n\n            3959 reviews\n    \n\n\n\n$$\n\n\nPizza\n\n\n\n\n\n\n\n\n\n            DUMBO        \n\n            1 Front StBrooklyn, NY 11201\n        \nPhone number\n\n        (718) 858-4300\n    \n\n\n\n\n\n\n\n\n\n\n\n\n                        Walked across the Brooklyn Bridge to get here. \xa0There was a line out the door. Although there was no sign-in system, we were unsure of how the seating worked. Waited in line and a…\n                        read more\n\n\n\n\n',
#  9: "\n\n\n\n\n\n\n\n\n\n\n\n\n\n9.         PN Wood Fired Pizza\n\n\n\n\n\n\n\n\n\n            60 reviews\n    \n\n\n\n$$\n\n\nPizza\n\n\n\n\n\n\n\n\n\n            Flatiron        \n\n            2 W 28th StNew York, NY 10001\n        \nPhone number\n\n        (844) 874-5864\n    \n\n\n\n\n\n\n\n\n\n\n\n\n                        I'd walked in only 2 hours before to book reservations for 5 people. Everyone was very helpful and kind at this restaurant right from the very beginning. We live on the west coast,…\n                        read more\n\n\n\n\n",
#  10: '\n\n\n\n\n\n\n\n\n\n\n\n\n\n10.         Joe’s Pizza\n\n\n\n\n\n\n\n\n\n            1457 reviews\n    \n\n\n\n$\n\n\nPizza\n\n\n\n\n\n\n\n\n\n            West Village        \n\n            7 Carmine StNew York, NY 10014\n        \nPhone number\n\n        (212) 366-1182\n    \n\n\n\n\n\n\n\n\n\n\n\n\n                        Delicious! I had 2 cheese slices and they were fantastic! Charred bottom gave them a satisfying crunch, sauce and cheese were excellent. \xa0 Despite the crowd, service was fast and…\n                        read more\n\n\n\n\n'}

# %%
clean = {index : " ".join(result.split()) for index, result in returned_text.items()}
pprint(clean)
# Out:
# {1: '1. Prince Street Pizza 800 reviews $ Pizza On the menu: Greene Machine '
#     'Pizza Nolita 27 Prince StNew York, NY 10012 Phone number (212) 966-4100 '
#     "I'm a big pizza fan and I just love to travel for Pizza. But this pizza "
#     'changed all that. Prince street pizza is hands down my favorite pizza in '
#     "NY. I pick this over Joe's. I… read more",
#  2: '2. Lombardi’s Pizza 4915 reviews $$ Pizza On the menu: White Pizza Nolita '
#     '32 Spring StNew York, NY 10012 Phone number (212) 941-7994 This place is '
#     "cool. There was a little bit of wait, but it wasn't too bad. But cash "
#     "only?? That's unheard of! The pizzas here are expensive, so being a cash "
#     'only place is not a good… read more',
#  3: '3. Juliana’s Pizza 1107 reviews $$ Pizza On the menu: Margherita pizza '
#     'DUMBO 19 Old Fulton StBrooklyn, NY 11201 Phone number (718) 596-6700 '
#     'Learned about this place from our Tour Guide and boy what a great '
#     'decision it was to come here, even though it was a bit of a wait. They '
#     'are spinning the dough in the front of the… read more',
#  4: '4. NY Pizza Suprema 1099 reviews $ Pizza Chelsea, Midtown West 413 8th '
#     'AveNew York, NY 10001 Phone number (212) 594-8939 This restaurant does '
#     'food delivery Start Order So glad I found this place. Definitely one of '
#     'my favorite pizza joints in NY they do justice to NYC pizza. a little on '
#     'the pricier side, but the taste is amazing. the crust is thin… read more',
#  5: '5. Patzeria Perfect Pizza 1043 reviews $ Pizza, Diners Theater District, '
#     'Midtown West 231 W 46th StNew York, NY 10036 Phone number (212) 575-7646 '
#     'Came on a whim because it was close to our hotel and we were HANGRY! .... '
#     'Oh boy, did we luck out! Pizza was amazing! Ordered sausage and '
#     'pepperoni, lasagna pizza, and ricotta,… read more',
#  6: '6. My Pie 312 reviews $ Italian, Pizza Midtown East 696 Lexington AveNew '
#     "York, NY 10022 Phone number (212) 317-1850 Thank God for my girlfriend's "
#     'Gluten Allergy. I never thought I would say that, but we tried this place '
#     'out after seeing on Yelp they offered GF Pizza. I stuck to regular '
#     'pizza,… read more',
#  7: '7. Adrienne’s Pizzabar 1069 reviews $$ Pizza, Italian Financial District '
#     '54 Stone StNew York, NY 10004 Phone number (212) 248-3838 Consistently '
#     'good pizza in the Financial District (FiDi). This place brings back '
#     'delicious memories. I moved to NYC in June 2009 and scored an incredible '
#     'deal on a Wall Street… read more',
#  8: '8. Grimaldi’s 3959 reviews $$ Pizza DUMBO 1 Front StBrooklyn, NY 11201 '
#     'Phone number (718) 858-4300 Walked across the Brooklyn Bridge to get '
#     'here. There was a line out the door. Although there was no sign-in '
#     'system, we were unsure of how the seating worked. Waited in line and a… '
#     'read more',
#  9: '9. PN Wood Fired Pizza 60 reviews $$ Pizza Flatiron 2 W 28th StNew York, '
#     "NY 10001 Phone number (844) 874-5864 I'd walked in only 2 hours before to "
#     'book reservations for 5 people. Everyone was very helpful and kind at '
#     'this restaurant right from the very beginning. We live on the west '
#     'coast,… read more',
#  10: '10. Joe’s Pizza 1457 reviews $ Pizza West Village 7 Carmine StNew York, '
#      'NY 10014 Phone number (212) 366-1182 Delicious! I had 2 cheese slices '
#      'and they were fantastic! Charred bottom gave them a satisfying crunch, '
#      'sauce and cheese were excellent. Despite the crowd, service was fast '
#      'and… read more'}

# %%
# Next page
soup.find_all('a', 'u-decoration-none next pagination-links_anchor', href = True)[0]['href']
# Out:
# '/search?find_desc=pizza&find_loc=New+York&start=10'
