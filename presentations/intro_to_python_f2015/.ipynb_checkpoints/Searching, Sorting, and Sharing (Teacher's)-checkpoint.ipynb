# %% [markdown]
# ## Welcome!
#
# ### This talk will introduce you to searching, sorting, and sharing using your favorite language and mine, Python!
#
# ### Python is a great language to quickly prototype and is backed by a great open-source community.
#
# <img src="python_ecosystem.jpg">

# %% [markdown]
# **Note: I adapted a ton of images from <a href="http://interactivepython.org/runestone/static/pythonds/index.html">Interactive Python</a>, check them out if you want to learn more about Python**
#
# ### We'll start with searching, and grow outwards from there.
#
# #### We want to start by importing numpy's random module, to generate random integers for our list of values

# %%
from IPython.display import display
import numpy.random as random

# %% [markdown]
# #### Let's initialize a list ```random_values``` of random values in the range [0,1000] using numpy's ```random.randint``` function (<a href="http://docs.scipy.org/doc/numpy/reference/generated/numpy.random.randint.html">documentation</a>)

# %%
# Will hold 1000 elements in the range 0 ~ 1000
random_values = [random.randint(1000) for x in range(1000)]

# %% [markdown]
# ### So how would we go about finding a particular key value in the list?
#
# Well, to be completely sure whether or not our key is in the list, we have to iterate through and ask: <br>
#
#     "Is the value at my current index equal to my key value (the value I'm looking for)?"
#
# If **yes**: "Awesome! Return ```True``` and break or whatever." <br>
# If **not**: "Lame. Keep on looking, though."

# %% [markdown]
# #### Let's print out the contents of our ```random_values``` list

# %%
# Let's take a look at our values list
print(random_values) # alternatively, ```random_values``` would also print our list
# Out:
# [341, 193, 978, 994, 13, 761, 534, 932, 599, 640, 883, 629, 210, 892, 862, 938, 730, 955, 32, 701, 293, 121, 822, 112, 349, 300, 688, 50, 654, 378, 431, 362, 485, 373, 958, 915, 484, 434, 902, 440, 623, 528, 889, 775, 251, 91, 97, 590, 396, 669, 919, 810, 362, 378, 716, 86, 906, 181, 230, 390, 837, 658, 827, 476, 976, 65, 692, 228, 73, 524, 298, 102, 67, 310, 704, 259, 996, 629, 367, 753, 511, 730, 104, 63, 297, 751, 604, 365, 595, 620, 530, 201, 992, 648, 587, 334, 621, 111, 754, 883, 55, 941, 838, 812, 86, 353, 386, 59, 124, 783, 634, 2, 817, 299, 603, 622, 945, 711, 942, 952, 419, 930, 140, 104, 288, 601, 940, 716, 139, 883, 642, 367, 169, 313, 683, 735, 102, 94, 244, 333, 518, 187, 713, 862, 459, 866, 806, 262, 256, 489, 62, 893, 133, 458, 757, 249, 152, 89, 829, 434, 898, 666, 689, 764, 456, 60, 260, 626, 723, 197, 4, 435, 908, 80, 755, 919, 230, 154, 52, 283, 75, 828, 865, 603, 315, 514, 234, 992, 543, 293, 760, 523, 93, 13, 911, 187, 993, 419, 176, 701, 19, 40, 2, 614, 817, 201, 688, 954, 301, 955, 758, 114, 703, 375, 729, 144, 682, 684, 582, 843, 400, 763, 991, 362, 728, 426, 471, 458, 708, 120, 971, 572, 615, 436, 310, 244, 408, 764, 756, 356, 286, 251, 650, 990, 756, 935, 217, 692, 491, 221, 633, 988, 179, 889, 328, 752, 698, 87, 820, 617, 92, 430, 626, 220, 282, 975, 910, 981, 121, 765, 831, 400, 78, 644, 719, 879, 323, 495, 246, 198, 958, 514, 380, 355, 678, 399, 867, 260, 965, 634, 783, 198, 180, 75, 788, 207, 500, 41, 590, 813, 892, 881, 118, 556, 255, 718, 521, 55, 564, 246, 365, 178, 449, 831, 599, 695, 190, 753, 624, 135, 128, 707, 252, 792, 891, 572, 156, 681, 883, 464, 184, 272, 756, 635, 222, 806, 221, 155, 689, 570, 116, 200, 6, 590, 803, 332, 275, 656, 974, 180, 554, 546, 750, 194, 378, 488, 61, 466, 167, 235, 746, 356, 987, 417, 163, 185, 497, 290, 771, 42, 662, 162, 401, 958, 298, 173, 242, 360, 465, 745, 702, 217, 355, 64, 263, 700, 84, 304, 837, 881, 331, 578, 630, 255, 319, 878, 847, 405, 276, 41, 531, 855, 43, 239, 735, 485, 764, 507, 636, 529, 897, 305, 796, 176, 135, 301, 244, 858, 709, 218, 232, 872, 382, 241, 696, 815, 906, 585, 82, 525, 743, 696, 6, 731, 784, 902, 826, 465, 549, 190, 825, 82, 862, 453, 848, 956, 231, 3, 873, 876, 821, 390, 447, 908, 427, 346, 334, 721, 950, 695, 23, 670, 814, 540, 253, 696, 833, 316, 72, 917, 321, 183, 782, 573, 741, 15, 732, 361, 491, 283, 881, 609, 755, 588, 126, 350, 55, 671, 622, 522, 466, 645, 658, 273, 832, 336, 52, 182, 295, 893, 428, 190, 160, 728, 278, 22, 299, 927, 541, 500, 643, 373, 107, 12, 744, 872, 950, 160, 718, 298, 425, 583, 770, 607, 169, 134, 32, 742, 574, 98, 466, 377, 232, 452, 61, 287, 288, 842, 731, 92, 456, 611, 568, 367, 300, 674, 857, 683, 612, 159, 173, 41, 657, 525, 287, 898, 405, 211, 96, 714, 209, 114, 283, 554, 828, 332, 229, 645, 462, 578, 222, 214, 469, 906, 879, 899, 26, 68, 291, 14, 226, 35, 975, 781, 71, 79, 371, 163, 391, 103, 924, 246, 7, 214, 867, 450, 116, 686, 633, 181, 982, 276, 501, 691, 730, 373, 744, 308, 630, 355, 85, 881, 199, 376, 299, 142, 251, 818, 868, 796, 951, 320, 899, 417, 189, 803, 63, 304, 600, 113, 168, 489, 494, 274, 947, 298, 633, 197, 524, 957, 103, 468, 112, 623, 278, 202, 536, 854, 676, 417, 251, 416, 133, 352, 444, 574, 523, 865, 356, 185, 299, 841, 708, 977, 868, 709, 405, 938, 417, 403, 658, 282, 189, 662, 495, 928, 51, 260, 237, 971, 708, 964, 639, 224, 271, 856, 809, 358, 806, 316, 590, 191, 599, 866, 551, 235, 637, 482, 78, 334, 425, 657, 257, 217, 790, 593, 914, 104, 466, 503, 108, 801, 147, 701, 748, 712, 951, 972, 241, 946, 432, 698, 975, 64, 619, 704, 634, 620, 169, 562, 261, 971, 680, 511, 563, 111, 562, 964, 976, 419, 362, 29, 622, 678, 991, 50, 12, 357, 214, 546, 206, 667, 675, 385, 540, 2, 355, 159, 634, 496, 704, 132, 8, 695, 914, 688, 68, 367, 40, 996, 140, 152, 311, 467, 888, 190, 845, 841, 629, 53, 469, 528, 426, 576, 144, 609, 434, 651, 331, 719, 948, 881, 146, 556, 397, 992, 297, 307, 964, 386, 864, 673, 693, 663, 516, 693, 261, 667, 725, 39, 163, 681, 896, 446, 312, 885, 451, 8 ...

# %% [markdown]
# ## Now we can linearly search three ways: the bad way, the better way, and the Pythonic way.
#
# <img src="linear_search.png">
#
# ### The bad way is to hard-code a loop through our values list.
# _Thought experiment_: Why is this bad? It works fine, right?
#
# Let's assume we're looking for the value ```516``` within our list. Let's code up our implementation (Note: for some of you, ```516``` won't be found in the list. That's fine!):

# %%
key = 516
for value in random_values:
    if value == key: 
        print("Found it!")
        break
# Out:
# Found it!

# %% [markdown]
# Here's what it looks like, visually:
#
# <img src="linear_search_done.png">
#
# You might have noticed that this isn't modular. We would have to rewrite each of these lines – key definition and iteration structure – for any possible list we want to iterate over. Kinda tedious.
#
# ### Now let's do it the semi-right way and make our linear search into a function
#
# We define a function ```linear_search```. What will the function need? We'll need an iterable object (i.e. a list) and we'll need a key value to search for. <br>
# So we say:

# %%
def linear_search(iterable, key):
    found = False
    for value in iterable:
        if value == key:
            found = True
            break
            
    return found

# %% [markdown]
# ### Why is this better than hardcoding our loop? Because this way, we can do more complex tasks, say:
#
# ```Given all numbers in the range of 0 to 1000, check if each number is in the random_values list.
# If it is, print "Found x" (where x is the number)```
#
# Let's do just that!

# %%
# Create our normal range from 0 to 1000
normal_values = [x for x in range(1000)]

# For each item in our normal_values list
for i in normal_values:
    # If our linear search evaluates to True, we print the number
    if linear_search(random_values, i) == True:
        print("Found {}!".format(i))
# Out:
# Found 2!
# Found 3!
# Found 4!
# Found 6!
# Found 7!
# Found 8!
# Found 12!
# Found 13!
# Found 14!
# Found 15!
# Found 19!
# Found 22!
# Found 23!
# Found 26!
# Found 29!
# Found 32!
# Found 34!
# Found 35!
# Found 39!
# Found 40!
# Found 41!
# Found 42!
# Found 43!
# Found 45!
# Found 50!
# Found 51!
# Found 52!
# Found 53!
# Found 55!
# Found 59!
# Found 60!
# Found 61!
# Found 62!
# Found 63!
# Found 64!
# Found 65!
# Found 67!
# Found 68!
# Found 71!
# Found 72!
# Found 73!
# Found 75!
# Found 78!
# Found 79!
# Found 80!
# Found 81!
# Found 82!
# Found 84!
# Found 85!
# Found 86!
# Found 87!
# Found 89!
# Found 91!
# Found 92!
# Found 93!
# Found 94!
# Found 95!
# Found 96!
# Found 97!
# Found 98!
# Found 100!
# Found 101!
# Found 102!
# Found 103!
# Found 104!
# Found 105!
# Found 107!
# Found 108!
# Found 109!
# Found 111!
# Found 112!
# Found 113!
# Found 114!
# Found 116!
# Found 118!
# Found 120!
# Found 121!
# Found 124!
# Found 126!
# Found 128!
# Found 131!
# Found 132!
# Found 133!
# Found 134!
# Found 135!
# Found 139!
# Found 140!
# Found 142!
# Found 144!
# Found 146!
# Found 147!
# Found 152!
# Found 154!
# Found 155!
# Found 156!
# Found 159!
# Found 160!
# Found 162!
# Found 163!
# Found 165!
# Found 167!
# Found 168!
# Found 169!
# Found 170!
# Found 171!
# Found 173!
# Found 176!
# Found 177!
# Found 178!
# Found 179!
# Found 180!
# Found 181!
# Found 182!
# Found 183!
# Found 184!
# Found 185!
# Found 187!
# Found 189!
# Found 190!
# Found 191!
# Found 193!
# Found 194!
# Found 197!
# Found 198!
# Found 199!
# Found 200!
# Found 201!
# Found 202!
# Found 206!
# Found 207!
# Found 208!
# Found 209!
# Found 210!
# Found 211!
# Found 212!
# Found 214!
# Found 215!
# Found 217!
# Found 218!
# Found 220!
# Found 221!
# Found 222!
# Found 224!
# Found 226!
# Found 227!
# Found 228!
# Found 229!
# Found 230!
# Found 231!
# Found 232!
# Found 234!
# Found 235!
# Found 236!
# Found 237!
# Found 239!
# Found 241!
# Found 242!
# Found 243!
# Found 244!
# Found 246!
# Found 249!
# Found 251!
# Found 252!
# Found 253!
# Found 255!
# Found 256!
# Found 257!
# Found 259!
# Found 260!
# Found 261!
# Found 262!
# Found 263!
# Found 266!
# Found 271!
# Found 272!
# Found 273!
# Found 274!
# Found 275!
# Found 276!
# Found 278!
# Found 282!
# Found 283!
# Found 286!
# Found 287!
# Found 288!
# Found 290!
# Found 291!
# Found 293!
# Found 295!
# Found 297!
# Found 298!
# Found 299!
# Found 300!
# Found 301!
# Found 304!
# Found 305!
# Found 307!
# Found 308!
# Found 310!
# Found 311!
# Found 312!
# Found 313!
# Found 315!
# Found 316!
# Found 317!
# Found 319!
# Found 320!
# Found 321!
# Found 322!
# Found 323!
# Found 328!
# Found 331!
# Found 332!
# Found 333!
# Found 334!
# Found 336!
# Found 338!
# Found 340!
# Found 341!
# Found 346!
# Found 349!
# Found 350!
# Found 352!
# Found 353!
# Found 355!
# Found 356!
# Found 357!
# Found 358!
# Found 360!
# Found 361!
# Found 362!
# Found 363!
# Found 365!
# Found 367!
# Found 371!
# Found 373!
# Found 375!
# Found 376!
# Found 377!
# Found 378!
# Found 380!
# Found 382!
# Found 385!
# Found 386!
# Found 390!
# Found 391!
# Found 395!
# Found 396!
# Found 397!
# Found 398!
# Found 399!
# Found 400!
# Found 401!
# Found 403!
# Found 404!
# Found 405!
# Found 408!
# Found 413!
# Found 414!
# Found 416!
# Found 417!
# Found 419!
# Found 425!
# Found 426!
# Found 427!
# Found 428!
# Found 429!
# Found 430!
# Found 431!
# Found 432!
# Found 434!
# Found 435!
# Found 436!
# Found 440!
# Found 442!
# Found 444!
# Found 446!
# Found 447!
# Found 449!
# Found 450!
# Found 451!
# Found 452!
# Found 453!
# Found 456!
# Found 458!
# Found 459!
# Found 462!
# Found 464!
# Found 465!
# Found 466!
# Found 467!
# Found 468!
# Found 469!
# Found 471!
# Found 474!
# Found 476!
# Found 478!
# Found 482!
# Found 484!
# Found 485!
# Found 487!
# Found 488!
# Found 489!
# Found 491!
# Found 494!
# Found 495!
# Found 496!
# Found 497!
# Found 500!
# Found 501!
# Found 503!
# Found 507!
# Found 508!
# Found 511!
# Found 512!
# Found 514!
# Found 516!
# Found 517!
# Found 518!
# Found 521!
# Found 522!
# Found 523!
# Found 524!
# Found 525!
# Found 527!
# Found 528!
# Found 529!
# Found 530!
# Found 531!
# Found 534!
# Found 536!
# Found 538!
# Found 540!
# Found 541!
# Found 542!
# Found 543!
# Found 546!
# Found 549!
# Found 551!
# Found 554!
# Found 556!
# Found 562!
# Found 563!
# Found 564!
# Found 568!
# Found 570!
# Found 572!
# Found 573!
# Found 574!
# Found 576!
# Found 577!
# Found 578!
# Found 581!
# Found 582!
# Found 583!
# Found 585!
# Found 587!
# Found 588!
# Found 589!
# Found 590!
# Found 593!
# Found 595!
# Found 599!
# Found 600!
# Found 601!
# Found 603!
# Found 604!
# Found 607!
# Found 608!
# Found 609!
# Found 611!
# Found 612!
# Found 614!
# Found 615!
# Found 617!
# Found 619!
# Found 620!
# Found 621!
# Found 622!
# Found 623!
# Found 624!
# Found 626!
# Found 629!
# Found 630!
# Found 633!
# Found 634!
# Found 635!
# Found 636!
# Found 637!
# Found 639!
# Found 640!
# Found 641!
# Found 642!
# Found 643!
# Found 644!
# Found 645!
# Found 648!
# Found 649!
# Found 650!
# Found 651!
# Found 654!
# Found 656!
# Found 657!
# Found 658!
# Found 662!
# Found 663!
# Found 666!
# Found 667!
# Found 669!
# Found 670!
# Found 671!
# Found 673!
# Found 674!
# Found 675!
# Found 676!
# Found 678!
# Found 680!
# Found 681!
# Found 682!
# Found 683!
# Found 684!
# Found 686!
# Found 688!
# Found 689!
# Found 691!
# Found 692!
# Found 693!
# Found 695!
# Found 696!
# Found 698!
# Found 700!
# Found 701!
# Found 702!
# Found 703!
# Found 704!
# Found 707!
# Found 708!
# Found 709!
# Found 711!
# Found 712!
# Found 713!
# Found 714!
# Found 715!
# Found 716!
# Found 718!
# Found 719!
# Found 720!
# Found 721!
# Found 723!
# Found 725!
# Found 728!
# Found 729!
# Found 730!
# Found 731!
# Found 732!
# Found 735!
# Found 741!
# Found 742!
# Found 743!
# Found 744!
# Found 745!
# Found 746!
# Found 748!
# Found 749!
# Found 750!
# Found 751!
# Found 752!
# Found 753!
# Found 754!
# Found 755!
# Found 756!
# Found 757!
# Found 758!
# Found 760!
# Found 761!
# Found 763!
# Found 764!
# Found 765!
# Found 769!
# Found 770!
# Found 771!
# Found 775!
# Found 777!
# Found 781!
# Found 782!
# Found 783!
# Found 784!
# Found 788!
# Found 790!
# Found 792!
# Found 796!
# Found 800!
# Found 801!
# Found 803!
# Found 804!
# Found 805!
# Found 806!
# Found 809!
# Found 810!
# Found 812!
# Found 813!
# Found 814!
# Found 815!
# Found 816!
# Found 817!
# Found 818!
# Found 820!
# Found 821!
# Found 822!
# Found 825!
# Found 826!
# Found 827!
# Found 828!
# Found 829!
# Found 831!
# Found 832!
# Found 833!
# Found 836!
# Found 837!
# Found 838!
# Found 841!
# Found 842!
# Found 843!
# Found 845!
# Found 847!
# Found 848!
# Found 849!
# Found 854!
# Found 855!
# Found 856!
# Found 857!
# Found 858!
# Found 862!
# Found 864!
# Found 865!
# Found 866!
# Found 867!
# Found 868!
# Found 872!
# Found 873!
# Found 876!
# Found 877!
# Found 878!
# Found 879!
# Found 881!
# Found 882!
# Found 883!
# Found 885!
# Found 888!
# Found 889!
# Found 890!
# Found 891!
# Found 892!
# Found 893!
# Found 896!
# Found 897!
# Found 898!
# Found 899!
# Found 902!
# Found 905!
# Found 906!
# Found 908!
# Found 909!
# Found 910!
# Found 911!
# Found 914!
# Found 915!
# Found 916!
# Found 917!
# Found 918!
# Found 919!
# Found 920!
# Found 924!
# Found 925!
# Found 927!
# Found 928!
# Found 930!
# Found 932!
# Found 935!
# Found 938!
# Found 940!
# Found 941!
# Found 942!
# Found 943!
# Found 944!
# Found 945!
# Found 946!
# Found 947!
# Found 948!
# Found 949!
# Found 950!
# Found 951!
# Found 952!
# Found 954!
# Found 955!
# Found 956!
# Found 957!
# Found 958!
# Found 961!
# Found 964!
# Found 965!
# Found 970!
# Found 971!
# Found 972!
# Found 974!
# Found 975!
# Found 976!
# Found 977!
# Found 978!
# Found 980!
# Found 981!
# Found 982!
# Found 986!
# Found 987!
# Found 988!
# Found 990!
# Found 991!
# Found 992!
# Found 993!
# Found 994!
# Found 996!

# %% [markdown]
# ### Now let's do it the Pythonic way
# Python has this nifty inclusion operator called ``in`` that we use all the time in our loops! Let's revisit our two previous examples using the ``in`` operator.

# %%
key = 516
key in random_values
# Out:
# True

# %%
for i in normal_values:
    if i in random_values:
        print("Found {}!".format(i))
# Out:
# Found 2!
# Found 3!
# Found 4!
# Found 6!
# Found 7!
# Found 8!
# Found 12!
# Found 13!
# Found 14!
# Found 15!
# Found 19!
# Found 22!
# Found 23!
# Found 26!
# Found 29!
# Found 32!
# Found 34!
# Found 35!
# Found 39!
# Found 40!
# Found 41!
# Found 42!
# Found 43!
# Found 45!
# Found 50!
# Found 51!
# Found 52!
# Found 53!
# Found 55!
# Found 59!
# Found 60!
# Found 61!
# Found 62!
# Found 63!
# Found 64!
# Found 65!
# Found 67!
# Found 68!
# Found 71!
# Found 72!
# Found 73!
# Found 75!
# Found 78!
# Found 79!
# Found 80!
# Found 81!
# Found 82!
# Found 84!
# Found 85!
# Found 86!
# Found 87!
# Found 89!
# Found 91!
# Found 92!
# Found 93!
# Found 94!
# Found 95!
# Found 96!
# Found 97!
# Found 98!
# Found 100!
# Found 101!
# Found 102!
# Found 103!
# Found 104!
# Found 105!
# Found 107!
# Found 108!
# Found 109!
# Found 111!
# Found 112!
# Found 113!
# Found 114!
# Found 116!
# Found 118!
# Found 120!
# Found 121!
# Found 124!
# Found 126!
# Found 128!
# Found 131!
# Found 132!
# Found 133!
# Found 134!
# Found 135!
# Found 139!
# Found 140!
# Found 142!
# Found 144!
# Found 146!
# Found 147!
# Found 152!
# Found 154!
# Found 155!
# Found 156!
# Found 159!
# Found 160!
# Found 162!
# Found 163!
# Found 165!
# Found 167!
# Found 168!
# Found 169!
# Found 170!
# Found 171!
# Found 173!
# Found 176!
# Found 177!
# Found 178!
# Found 179!
# Found 180!
# Found 181!
# Found 182!
# Found 183!
# Found 184!
# Found 185!
# Found 187!
# Found 189!
# Found 190!
# Found 191!
# Found 193!
# Found 194!
# Found 197!
# Found 198!
# Found 199!
# Found 200!
# Found 201!
# Found 202!
# Found 206!
# Found 207!
# Found 208!
# Found 209!
# Found 210!
# Found 211!
# Found 212!
# Found 214!
# Found 215!
# Found 217!
# Found 218!
# Found 220!
# Found 221!
# Found 222!
# Found 224!
# Found 226!
# Found 227!
# Found 228!
# Found 229!
# Found 230!
# Found 231!
# Found 232!
# Found 234!
# Found 235!
# Found 236!
# Found 237!
# Found 239!
# Found 241!
# Found 242!
# Found 243!
# Found 244!
# Found 246!
# Found 249!
# Found 251!
# Found 252!
# Found 253!
# Found 255!
# Found 256!
# Found 257!
# Found 259!
# Found 260!
# Found 261!
# Found 262!
# Found 263!
# Found 266!
# Found 271!
# Found 272!
# Found 273!
# Found 274!
# Found 275!
# Found 276!
# Found 278!
# Found 282!
# Found 283!
# Found 286!
# Found 287!
# Found 288!
# Found 290!
# Found 291!
# Found 293!
# Found 295!
# Found 297!
# Found 298!
# Found 299!
# Found 300!
# Found 301!
# Found 304!
# Found 305!
# Found 307!
# Found 308!
# Found 310!
# Found 311!
# Found 312!
# Found 313!
# Found 315!
# Found 316!
# Found 317!
# Found 319!
# Found 320!
# Found 321!
# Found 322!
# Found 323!
# Found 328!
# Found 331!
# Found 332!
# Found 333!
# Found 334!
# Found 336!
# Found 338!
# Found 340!
# Found 341!
# Found 346!
# Found 349!
# Found 350!
# Found 352!
# Found 353!
# Found 355!
# Found 356!
# Found 357!
# Found 358!
# Found 360!
# Found 361!
# Found 362!
# Found 363!
# Found 365!
# Found 367!
# Found 371!
# Found 373!
# Found 375!
# Found 376!
# Found 377!
# Found 378!
# Found 380!
# Found 382!
# Found 385!
# Found 386!
# Found 390!
# Found 391!
# Found 395!
# Found 396!
# Found 397!
# Found 398!
# Found 399!
# Found 400!
# Found 401!
# Found 403!
# Found 404!
# Found 405!
# Found 408!
# Found 413!
# Found 414!
# Found 416!
# Found 417!
# Found 419!
# Found 425!
# Found 426!
# Found 427!
# Found 428!
# Found 429!
# Found 430!
# Found 431!
# Found 432!
# Found 434!
# Found 435!
# Found 436!
# Found 440!
# Found 442!
# Found 444!
# Found 446!
# Found 447!
# Found 449!
# Found 450!
# Found 451!
# Found 452!
# Found 453!
# Found 456!
# Found 458!
# Found 459!
# Found 462!
# Found 464!
# Found 465!
# Found 466!
# Found 467!
# Found 468!
# Found 469!
# Found 471!
# Found 474!
# Found 476!
# Found 478!
# Found 482!
# Found 484!
# Found 485!
# Found 487!
# Found 488!
# Found 489!
# Found 491!
# Found 494!
# Found 495!
# Found 496!
# Found 497!
# Found 500!
# Found 501!
# Found 503!
# Found 507!
# Found 508!
# Found 511!
# Found 512!
# Found 514!
# Found 516!
# Found 517!
# Found 518!
# Found 521!
# Found 522!
# Found 523!
# Found 524!
# Found 525!
# Found 527!
# Found 528!
# Found 529!
# Found 530!
# Found 531!
# Found 534!
# Found 536!
# Found 538!
# Found 540!
# Found 541!
# Found 542!
# Found 543!
# Found 546!
# Found 549!
# Found 551!
# Found 554!
# Found 556!
# Found 562!
# Found 563!
# Found 564!
# Found 568!
# Found 570!
# Found 572!
# Found 573!
# Found 574!
# Found 576!
# Found 577!
# Found 578!
# Found 581!
# Found 582!
# Found 583!
# Found 585!
# Found 587!
# Found 588!
# Found 589!
# Found 590!
# Found 593!
# Found 595!
# Found 599!
# Found 600!
# Found 601!
# Found 603!
# Found 604!
# Found 607!
# Found 608!
# Found 609!
# Found 611!
# Found 612!
# Found 614!
# Found 615!
# Found 617!
# Found 619!
# Found 620!
# Found 621!
# Found 622!
# Found 623!
# Found 624!
# Found 626!
# Found 629!
# Found 630!
# Found 633!
# Found 634!
# Found 635!
# Found 636!
# Found 637!
# Found 639!
# Found 640!
# Found 641!
# Found 642!
# Found 643!
# Found 644!
# Found 645!
# Found 648!
# Found 649!
# Found 650!
# Found 651!
# Found 654!
# Found 656!
# Found 657!
# Found 658!
# Found 662!
# Found 663!
# Found 666!
# Found 667!
# Found 669!
# Found 670!
# Found 671!
# Found 673!
# Found 674!
# Found 675!
# Found 676!
# Found 678!
# Found 680!
# Found 681!
# Found 682!
# Found 683!
# Found 684!
# Found 686!
# Found 688!
# Found 689!
# Found 691!
# Found 692!
# Found 693!
# Found 695!
# Found 696!
# Found 698!
# Found 700!
# Found 701!
# Found 702!
# Found 703!
# Found 704!
# Found 707!
# Found 708!
# Found 709!
# Found 711!
# Found 712!
# Found 713!
# Found 714!
# Found 715!
# Found 716!
# Found 718!
# Found 719!
# Found 720!
# Found 721!
# Found 723!
# Found 725!
# Found 728!
# Found 729!
# Found 730!
# Found 731!
# Found 732!
# Found 735!
# Found 741!
# Found 742!
# Found 743!
# Found 744!
# Found 745!
# Found 746!
# Found 748!
# Found 749!
# Found 750!
# Found 751!
# Found 752!
# Found 753!
# Found 754!
# Found 755!
# Found 756!
# Found 757!
# Found 758!
# Found 760!
# Found 761!
# Found 763!
# Found 764!
# Found 765!
# Found 769!
# Found 770!
# Found 771!
# Found 775!
# Found 777!
# Found 781!
# Found 782!
# Found 783!
# Found 784!
# Found 788!
# Found 790!
# Found 792!
# Found 796!
# Found 800!
# Found 801!
# Found 803!
# Found 804!
# Found 805!
# Found 806!
# Found 809!
# Found 810!
# Found 812!
# Found 813!
# Found 814!
# Found 815!
# Found 816!
# Found 817!
# Found 818!
# Found 820!
# Found 821!
# Found 822!
# Found 825!
# Found 826!
# Found 827!
# Found 828!
# Found 829!
# Found 831!
# Found 832!
# Found 833!
# Found 836!
# Found 837!
# Found 838!
# Found 841!
# Found 842!
# Found 843!
# Found 845!
# Found 847!
# Found 848!
# Found 849!
# Found 854!
# Found 855!
# Found 856!
# Found 857!
# Found 858!
# Found 862!
# Found 864!
# Found 865!
# Found 866!
# Found 867!
# Found 868!
# Found 872!
# Found 873!
# Found 876!
# Found 877!
# Found 878!
# Found 879!
# Found 881!
# Found 882!
# Found 883!
# Found 885!
# Found 888!
# Found 889!
# Found 890!
# Found 891!
# Found 892!
# Found 893!
# Found 896!
# Found 897!
# Found 898!
# Found 899!
# Found 902!
# Found 905!
# Found 906!
# Found 908!
# Found 909!
# Found 910!
# Found 911!
# Found 914!
# Found 915!
# Found 916!
# Found 917!
# Found 918!
# Found 919!
# Found 920!
# Found 924!
# Found 925!
# Found 927!
# Found 928!
# Found 930!
# Found 932!
# Found 935!
# Found 938!
# Found 940!
# Found 941!
# Found 942!
# Found 943!
# Found 944!
# Found 945!
# Found 946!
# Found 947!
# Found 948!
# Found 949!
# Found 950!
# Found 951!
# Found 952!
# Found 954!
# Found 955!
# Found 956!
# Found 957!
# Found 958!
# Found 961!
# Found 964!
# Found 965!
# Found 970!
# Found 971!
# Found 972!
# Found 974!
# Found 975!
# Found 976!
# Found 977!
# Found 978!
# Found 980!
# Found 981!
# Found 982!
# Found 986!
# Found 987!
# Found 988!
# Found 990!
# Found 991!
# Found 992!
# Found 993!
# Found 994!
# Found 996!

# %% [markdown]
# ## Let's talk about binary search
# So linear search is cool and all, but what about something faster? Well, we can improve our searching if we *know* that our collection is in sorted order.
#
# Let's sort our ```random_values``` list:

# %%
sorted_values = sorted(random_values)

# %% [markdown]
# Now we can take advantage of our sorted values and say: compare my ```key``` against the middle value within my list. From there, we evaluate:
#
# **Is my ```key``` value greater than the list's value at the middle index? Is it less than? Equal to?**
#
# If our ```key``` is found, then we're done. For our purposes, let's say our key is *greater than* the value at the middle of the list. Since our list is sorted, we **know** we won't find it *below* the middle value. Therefore, we can eliminate *half of our search space* and only consider the upper half of our list when re-searching.
#
# <img src="bin_search.png">
#
# Let's implement binary search recursively:

# %%
def rec_binary_search(list_of_values, key):
    # if our list is empty, we can't find key
    if len(list_of_values) == 0:
        return "{} was not found".format(key)
    else:
        
        mid = len(list_of_values) // 2
        if key > list_of_values[mid]:
            return rec_binary_search(list_of_values[mid+1:], key)
        elif key < list_of_values[mid]:
            return rec_binary_search(list_of_values[:mid], key)
        else:
            return "{} was found".format(key)

# %% [markdown]
# Let's implement binary search iteratively:

# %%
def iter_binary_search(list_of_values, key):
    left_index = 0
    right_index = len(list_of_values) - 1
    
    while (left_index <= right_index):
        mid = (left_index + right_index) // 2
        if key > list_of_values[mid]:
            left_index = mid + 1
        elif key < list_of_values[mid]:
            right_index = mid - 1
        else:
            return "{} was found".format(key)
        
    return "{} was not found".format(key)

# %%
list_of_values = [17, 20, 26, 31, 44, 54, 55, 65, 77, 93]
for value in list_of_values:
    print(rec_binary_search(list_of_values, value))
    print(iter_binary_search(list_of_values, value))
# Out:
# 17 was found
# 17 was found
# 20 was found
# 20 was found
# 26 was found
# 26 was found
# 31 was found
# 31 was found
# 44 was found
# 44 was found
# 54 was found
# 54 was found
# 55 was found
# 55 was found
# 65 was found
# 65 was found
# 77 was found
# 77 was found
# 93 was found
# 93 was found

# %% [markdown]
# Cool! So we've that wraps up searching in Python. Next, we introduce sorting.

# %% [markdown]
# # Sorting
#
# Sorting is the (not-so) simple task of taking a collection of values/objects/etc. and arranging them in a cohesive, sorted order (ascending *or* descending). We all (hopefully) know the basic sorting methods, including selection, insertion, and bubble sorts.
#
# We'll introduce two more advanced sorting methods -- mergesort and quicksort -- that are much quicker than the previously mentioned sorting algorithms. Note that we won't be covering the **very advanced, objectively necessary** <a href="http://rosettacode.org/wiki/Sorting_algorithms/Sleep_sort">sleep sort</a> or <a href="https://en.wikipedia.org/wiki/Bogosort">bogo sort</a> algorithms (sleep sort sorts any list of numbers in O(n) time -- true story)*.
#
# With that, let's approach mergesort.
#
# \* I'm totally kidding.
#
#
# ## Mergesort
#
# Mergesort is a recursive sorting algorithm that recursively splits a list in half until it's dealing with a list of size 1. By definition, a list of size 0 or 1 is considered sorted. Ergo, if the list has a size of 2 or more, we recursively split it in half and invoke merge sort on both halves.
#
# A vital part of merge sort is the *merge* operation, which is done once each half is sorted. Merging is where we take two sorted sub-arrays and merge them into a single, sorted, list.
#
# Let's see if we can visualize it. Take our list:
#
#                         | 10 | 12 | 34 | 58 | 43 | 25 | 19 | 61 | 49 | 32 |
#
# We note that it's length is greater than 1, so (by our definition) it's unsorted. We first recursively break the problem into half by recursively calling mergesort on the first half of the list while the list's length is greater than 1. I've put an asterisk * next to the arrays that are considered sorted. Ergo:
#
#                         | 10 | 12 | 34 | 58 | 43 | 25 | 19 | 61 | 49 | 32 |
#                                    /                           \
#             | 10 | 12 | 34 | 58 | 43 |                       | 25 | 19 | 61 | 49 | 32 |
#                      /      \                                         /      \
#           | 10 | 12 |        | 34 | 58 | 43 |              | 25 | 19 |        | 61 | 49 | 32 |
#               / \                /      \                      / \                /      \
#         | 10 |*  | 12 |*   | 34 |*       | 58 | 43 |     | 25 |*  | 19 |*   | 61 |*       | 49 | 32 |
#                                              / \                                              / \
#                                        | 58 |*  | 43 |*                                | 49 |*   | 32 |*
#
# Once we've gotten to the point where each array is now of size 1, we join them back together in sorted order. Consider our right-most branch, containing ```49``` in our left array and ```32``` in our right array. In this case, we would iterate through both arrays and compare the available value (which, in this case, is only ```49``` and ```32```). Ergo, the result of joining them together will result in the array: ```| 32 | 49 |*```. Visually joining the lists back, we see:
#
#         | 10 |*  | 12 |*       | 34 |*  | 58 |* | 43 |*  | 25 |*  | 19 |*  | 61 |*  | 49 |*  | 32 |*
#         |--- merge ---|                 |-- merge ---|   |--- merge ---|            |--- merge ---|
#           | 10 | 12 |*                   | 43 | 58 |*      | 19 | 25 |*               | 32 | 49 |*
#                                |------- merge -------|                     |------- merge --------|
#                                   | 34 | 43 | 58 |*                           | 32 | 49 | 61 |*
#           |----------------- merge ------------------|     |--------------- merge ----------------|
#                   | 10 | 12 | 34 | 43 | 58 |*                     | 19 | 25 | 32 | 49 | 61 |*
#                   |------------------------------- merge ----------------------------------|
#                             | 10 | 12 | 19 | 25 | 32 | 34 | 43 | 49 | 58 | 61 |*
#
# Nothing to it, right? Let's implement a recursive mergesort:

# %%
def mergesort(list_of_values):
    # if we have a list longer than 1, break it up into two at the midpoint
    if len(list_of_values) > 1:
        # get our midpoint
        mid = len(list_of_values) // 2
        # break our list into two halfs -- left and right -- by splicing
        left_half = list_of_values[:mid]
        right_half = list_of_values[mid:]
        # recursively break the list into halves
        mergesort(left_half)
        mergesort(right_half)
        # at this point, we assume the left and right halves are sorted
        # hold index values for each halved array, plus our original
        left_index = 0
        left_length = len(left_half)
        right_index = 0
        right_length = len(right_half)
        merged_index = 0
        # iterate through each list while you can do so for both (very important!)
        # and compare the values at our respective indices
        while left_index < left_length and right_index < right_length:
            # for whichever value in either array, the *smaller* is placed into the merged array
            # and increment the respective index to look at the next value
            if left_half[left_index] < right_half[right_index]:
                list_of_values[merged_index] = left_half[left_index]
                left_index += 1
            elif left_half[left_index] > right_half[right_index]:
                list_of_values[merged_index] = right_half[right_index]
                right_index += 1
            # regardless, we increase the merged list's index
            merged_index += 1
        # if we've run through one of the halves, we can just copy the other
        # these two blocks of code do just that: copy whatever's left (if anything)
        # in both arrays into the merged list_of_values
        while left_index < left_length:
            list_of_values[merged_index] = left_half[left_index]
            left_index += 1
            merged_index += 1
        while right_index < right_length:
            list_of_values[merged_index] = right_half[right_index]
            right_index += 1
            merged_index += 1

            
            
def mergesort_alt(alist):
    if len(alist)>1:
        mid = len(alist)//2
        lefthalf = alist[:mid]
        righthalf = alist[mid:]

        mergesort_alt(lefthalf)
        mergesort_alt(righthalf)

        i=0
        j=0
        k=0
        while i < len(lefthalf) and j < len(righthalf):
            if lefthalf[i] < righthalf[j]:
                alist[k]=lefthalf[i]
                i=i+1
            else:
                alist[k]=righthalf[j]
                j=j+1
            k=k+1

        while i < len(lefthalf):
            alist[k]=lefthalf[i]
            i=i+1
            k=k+1

        while j < len(righthalf):
            alist[k]=righthalf[j]
            j=j+1
            k=k+1

# %% [markdown]
# Let's test out our merge sort on our list ```random_values```

# %%
# random_values
mergesort(random_values)

# %% [markdown]
# ## Feel free to check out any of the following links for more resources on Python:
# <a href="http://interactivepython.org/runestone/static/pythonds/index.html">Interactive Python</a>: A great open source repository for interactive textbooks, including one on problem solving in Python. <br>
# <a href="http://www.amazon.com/Python-Cookbook-Alex-Martelli/dp/0596007973/">Python Cookbook</a>: Good collection of problems to solve and projects to undertake using Python <br>
# <a href="http://flask.pocoo.org/docs/0.10/">Flask</a>: A microframework for Python web development. <br>
#
# <a href="http://nbviewer.ipython.org/">nbviewer</a>
#
# # Thanks!
