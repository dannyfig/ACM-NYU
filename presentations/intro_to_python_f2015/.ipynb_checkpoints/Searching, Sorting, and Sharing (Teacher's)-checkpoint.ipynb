# %% [markdown]
# ## Welcome!
#
# ### This talk will introduce you to searching, sorting, and sharing using your favorite language and mine, Python!
#
# ### Python is a great language to quickly prototype and is backed by a great open-source community.
#
# <img src="python_ecosystem.jpg">

# %% [markdown]
# **Note: I adapted a ton of images from <a href="http://interactivepython.org/runestone/static/pythonds/index.html">Interactive Python</a>, check them out if you want to learn more about Python**
#
# ### We'll start with searching, and grow outwards from there.
#
# #### We want to start by importing numpy's random module, to generate random integers for our list of values

# %%
from IPython.display import display
import numpy.random as random

# %% [markdown]
# #### Let's initialize a list ```random_values``` of random values in the range [0,1000] using numpy's ```random.randint``` function (<a href="http://docs.scipy.org/doc/numpy/reference/generated/numpy.random.randint.html">documentation</a>)

# %%
# Will hold 1000 elements in the range 0 ~ 1000
random_values = [random.randint(1000) for x in range(1000)]

# %% [markdown]
# ### So how would we go about finding a particular key value in the list?
#
# Well, to be completely sure whether or not our key is in the list, we have to iterate through and ask: <br>
#
#     "Is the value at my current index equal to my key value (the value I'm looking for)?"
#
# If **yes**: "Awesome! Return ```True``` and break or whatever." <br>
# If **not**: "Lame. Keep on looking, though."

# %% [markdown]
# #### Let's print out the contents of our ```random_values``` list

# %%
# Let's take a look at our values list
print(random_values) # alternatively, ```random_values``` would also print our list
# Out:
# [76, 654, 82, 890, 608, 124, 636, 685, 163, 907, 208, 484, 372, 605, 538, 434, 708, 428, 57, 847, 261, 259, 249, 125, 567, 474, 514, 830, 695, 646, 855, 94, 182, 228, 402, 622, 155, 608, 992, 992, 610, 794, 40, 992, 353, 130, 829, 557, 983, 52, 475, 800, 423, 279, 645, 695, 70, 209, 925, 412, 730, 807, 364, 354, 913, 26, 493, 32, 863, 0, 110, 565, 319, 896, 45, 459, 595, 401, 38, 428, 692, 931, 396, 658, 857, 776, 154, 830, 983, 398, 22, 971, 286, 181, 750, 755, 924, 226, 432, 462, 502, 555, 721, 273, 211, 484, 436, 116, 561, 585, 263, 175, 785, 106, 636, 828, 582, 583, 563, 775, 287, 42, 856, 406, 598, 699, 952, 234, 87, 381, 870, 617, 538, 775, 327, 373, 962, 110, 147, 226, 231, 108, 43, 887, 217, 42, 812, 652, 476, 703, 588, 283, 582, 411, 761, 743, 142, 952, 670, 169, 799, 955, 688, 228, 784, 45, 95, 564, 486, 389, 304, 375, 96, 986, 975, 700, 548, 118, 484, 427, 702, 493, 458, 894, 419, 16, 60, 599, 509, 346, 820, 67, 396, 173, 256, 676, 665, 829, 938, 275, 198, 32, 465, 207, 362, 457, 151, 873, 977, 866, 472, 959, 734, 273, 784, 314, 680, 425, 383, 914, 774, 126, 290, 326, 354, 664, 167, 423, 469, 573, 804, 132, 156, 837, 749, 840, 736, 573, 410, 118, 642, 690, 776, 20, 879, 59, 239, 465, 98, 549, 288, 241, 216, 192, 513, 876, 962, 711, 670, 980, 303, 532, 249, 599, 87, 76, 13, 799, 887, 973, 583, 99, 799, 451, 883, 485, 401, 390, 900, 95, 762, 813, 641, 776, 190, 736, 716, 7, 394, 819, 322, 836, 840, 785, 566, 278, 638, 848, 456, 361, 397, 580, 365, 616, 693, 132, 395, 361, 527, 540, 4, 163, 990, 812, 839, 411, 389, 369, 673, 949, 718, 544, 993, 814, 267, 163, 822, 72, 261, 966, 188, 256, 268, 640, 499, 34, 472, 714, 334, 657, 661, 414, 289, 595, 601, 873, 375, 974, 872, 387, 880, 577, 191, 183, 829, 713, 342, 415, 27, 572, 827, 528, 768, 372, 763, 884, 764, 887, 704, 150, 741, 551, 720, 213, 517, 840, 195, 903, 435, 452, 433, 498, 150, 872, 453, 200, 377, 569, 639, 425, 64, 513, 409, 50, 81, 853, 773, 102, 107, 285, 401, 706, 406, 922, 20, 259, 610, 351, 621, 754, 633, 680, 325, 899, 525, 431, 981, 968, 180, 541, 519, 630, 476, 53, 620, 396, 576, 261, 49, 957, 146, 378, 553, 181, 688, 978, 41, 424, 641, 155, 551, 397, 0, 21, 537, 864, 576, 559, 343, 353, 724, 324, 357, 742, 254, 802, 154, 71, 386, 162, 548, 823, 190, 459, 169, 440, 499, 905, 376, 986, 478, 521, 770, 28, 146, 170, 472, 635, 704, 446, 700, 680, 507, 384, 605, 836, 367, 13, 268, 484, 670, 690, 412, 414, 698, 490, 497, 631, 233, 630, 776, 452, 271, 288, 772, 455, 363, 139, 516, 226, 687, 854, 550, 555, 616, 424, 803, 966, 814, 602, 828, 294, 48, 563, 395, 866, 892, 88, 432, 180, 817, 442, 965, 913, 647, 363, 317, 928, 848, 621, 195, 647, 539, 691, 527, 634, 192, 689, 857, 213, 484, 118, 916, 302, 281, 656, 268, 487, 232, 318, 253, 158, 96, 341, 469, 509, 586, 42, 660, 411, 620, 236, 341, 33, 881, 978, 835, 208, 923, 389, 489, 953, 580, 93, 258, 746, 770, 784, 882, 991, 464, 212, 780, 507, 21, 548, 861, 336, 185, 491, 992, 400, 354, 640, 664, 964, 590, 402, 854, 928, 106, 537, 384, 803, 879, 180, 531, 501, 194, 650, 415, 277, 439, 228, 389, 479, 373, 742, 359, 725, 218, 686, 584, 113, 511, 520, 32, 511, 836, 37, 10, 694, 87, 480, 910, 340, 356, 654, 698, 202, 73, 976, 832, 433, 513, 397, 330, 433, 489, 721, 412, 426, 633, 596, 93, 870, 20, 422, 907, 803, 113, 118, 993, 545, 122, 82, 722, 591, 782, 436, 468, 734, 128, 704, 817, 801, 152, 327, 459, 138, 714, 264, 104, 667, 13, 321, 788, 417, 926, 751, 303, 262, 745, 114, 365, 182, 867, 698, 360, 912, 536, 890, 819, 218, 118, 770, 143, 738, 246, 60, 933, 453, 450, 988, 706, 597, 506, 693, 508, 420, 67, 618, 503, 128, 795, 566, 914, 868, 880, 168, 151, 466, 11, 108, 218, 303, 70, 580, 259, 421, 876, 56, 29, 610, 396, 886, 414, 46, 797, 407, 571, 156, 694, 925, 637, 274, 586, 349, 1, 49, 769, 74, 233, 999, 933, 318, 189, 592, 777, 284, 363, 810, 20, 767, 124, 808, 544, 261, 20, 508, 52, 361, 115, 615, 540, 832, 831, 604, 106, 582, 7, 862, 558, 981, 870, 33, 112, 211, 363, 385, 938, 421, 989, 189, 901, 460, 295,  ...

# %% [markdown]
# ## Now we can linearly search three ways: the bad way, the better way, and the Pythonic way.
#
# <img src="linear_search.png">
#
# ### The bad way is to hard-code a loop through our values list.
# _Thought experiment_: Why is this bad? It works fine, right?
#
# Let's assume we're looking for the value ```516``` within our list. Let's code up our implementation (Note: for some of you, ```516``` won't be found in the list. That's fine!):

# %%
key = 516
for value in random_values:
    if value == key: 
        print("Found it!")
        break
# Out:
# Found it!

# %% [markdown]
# Here's what it looks like, visually:
#
# <img src="linear_search_done.png">
#
# You might have noticed that this isn't modular. We would have to rewrite each of these lines – key definition and iteration structure – for any possible list we want to iterate over. Kinda tedious.
#
# ### Now let's do it the semi-right way and make our linear search into a function
#
# We define a function ```linear_search```. What will the function need? We'll need an iterable object (i.e. a list) and we'll need a key value to search for. <br>
# So we say:

# %%
def linear_search(iterable, key):
    found = False
    for value in iterable:
        if value == key:
            found = True
            break
            
    return found

# %% [markdown]
# ### Why is this better than hardcoding our loop? Because this way, we can do more complex tasks, say:
#
# ```Given all numbers in the range of 0 to 1000, check if each number is in the random_values list.
# If it is, print "Found x" (where x is the number)```
#
# Let's do just that!

# %%
# Create our normal range from 0 to 1000
normal_values = [x for x in range(1000)]

# For each item in our normal_values list
for i in normal_values:
    # If our linear search evaluates to True, we print the number
    if linear_search(random_values, i) == True:
        print("Found {}!".format(i))
# Out:
# Found 0!
# Found 1!
# Found 4!
# Found 5!
# Found 7!
# Found 10!
# Found 11!
# Found 13!
# Found 16!
# Found 18!
# Found 20!
# Found 21!
# Found 22!
# Found 23!
# Found 26!
# Found 27!
# Found 28!
# Found 29!
# Found 32!
# Found 33!
# Found 34!
# Found 35!
# Found 37!
# Found 38!
# Found 40!
# Found 41!
# Found 42!
# Found 43!
# Found 44!
# Found 45!
# Found 46!
# Found 48!
# Found 49!
# Found 50!
# Found 52!
# Found 53!
# Found 55!
# Found 56!
# Found 57!
# Found 59!
# Found 60!
# Found 64!
# Found 67!
# Found 69!
# Found 70!
# Found 71!
# Found 72!
# Found 73!
# Found 74!
# Found 75!
# Found 76!
# Found 81!
# Found 82!
# Found 85!
# Found 87!
# Found 88!
# Found 89!
# Found 93!
# Found 94!
# Found 95!
# Found 96!
# Found 98!
# Found 99!
# Found 102!
# Found 104!
# Found 106!
# Found 107!
# Found 108!
# Found 110!
# Found 112!
# Found 113!
# Found 114!
# Found 115!
# Found 116!
# Found 118!
# Found 122!
# Found 124!
# Found 125!
# Found 126!
# Found 128!
# Found 130!
# Found 132!
# Found 138!
# Found 139!
# Found 142!
# Found 143!
# Found 146!
# Found 147!
# Found 149!
# Found 150!
# Found 151!
# Found 152!
# Found 154!
# Found 155!
# Found 156!
# Found 158!
# Found 162!
# Found 163!
# Found 167!
# Found 168!
# Found 169!
# Found 170!
# Found 172!
# Found 173!
# Found 175!
# Found 177!
# Found 180!
# Found 181!
# Found 182!
# Found 183!
# Found 184!
# Found 185!
# Found 188!
# Found 189!
# Found 190!
# Found 191!
# Found 192!
# Found 194!
# Found 195!
# Found 198!
# Found 200!
# Found 202!
# Found 205!
# Found 207!
# Found 208!
# Found 209!
# Found 211!
# Found 212!
# Found 213!
# Found 216!
# Found 217!
# Found 218!
# Found 221!
# Found 222!
# Found 226!
# Found 228!
# Found 231!
# Found 232!
# Found 233!
# Found 234!
# Found 236!
# Found 239!
# Found 240!
# Found 241!
# Found 243!
# Found 244!
# Found 246!
# Found 249!
# Found 253!
# Found 254!
# Found 255!
# Found 256!
# Found 258!
# Found 259!
# Found 261!
# Found 262!
# Found 263!
# Found 264!
# Found 267!
# Found 268!
# Found 271!
# Found 273!
# Found 274!
# Found 275!
# Found 276!
# Found 277!
# Found 278!
# Found 279!
# Found 281!
# Found 283!
# Found 284!
# Found 285!
# Found 286!
# Found 287!
# Found 288!
# Found 289!
# Found 290!
# Found 294!
# Found 295!
# Found 297!
# Found 299!
# Found 301!
# Found 302!
# Found 303!
# Found 304!
# Found 311!
# Found 314!
# Found 317!
# Found 318!
# Found 319!
# Found 321!
# Found 322!
# Found 324!
# Found 325!
# Found 326!
# Found 327!
# Found 330!
# Found 334!
# Found 336!
# Found 338!
# Found 340!
# Found 341!
# Found 342!
# Found 343!
# Found 346!
# Found 348!
# Found 349!
# Found 350!
# Found 351!
# Found 353!
# Found 354!
# Found 356!
# Found 357!
# Found 359!
# Found 360!
# Found 361!
# Found 362!
# Found 363!
# Found 364!
# Found 365!
# Found 367!
# Found 369!
# Found 372!
# Found 373!
# Found 374!
# Found 375!
# Found 376!
# Found 377!
# Found 378!
# Found 381!
# Found 383!
# Found 384!
# Found 385!
# Found 386!
# Found 387!
# Found 389!
# Found 390!
# Found 391!
# Found 394!
# Found 395!
# Found 396!
# Found 397!
# Found 398!
# Found 400!
# Found 401!
# Found 402!
# Found 404!
# Found 406!
# Found 407!
# Found 409!
# Found 410!
# Found 411!
# Found 412!
# Found 414!
# Found 415!
# Found 416!
# Found 417!
# Found 419!
# Found 420!
# Found 421!
# Found 422!
# Found 423!
# Found 424!
# Found 425!
# Found 426!
# Found 427!
# Found 428!
# Found 430!
# Found 431!
# Found 432!
# Found 433!
# Found 434!
# Found 435!
# Found 436!
# Found 438!
# Found 439!
# Found 440!
# Found 442!
# Found 445!
# Found 446!
# Found 450!
# Found 451!
# Found 452!
# Found 453!
# Found 455!
# Found 456!
# Found 457!
# Found 458!
# Found 459!
# Found 460!
# Found 461!
# Found 462!
# Found 464!
# Found 465!
# Found 466!
# Found 468!
# Found 469!
# Found 471!
# Found 472!
# Found 474!
# Found 475!
# Found 476!
# Found 478!
# Found 479!
# Found 480!
# Found 484!
# Found 485!
# Found 486!
# Found 487!
# Found 489!
# Found 490!
# Found 491!
# Found 493!
# Found 496!
# Found 497!
# Found 498!
# Found 499!
# Found 501!
# Found 502!
# Found 503!
# Found 506!
# Found 507!
# Found 508!
# Found 509!
# Found 511!
# Found 513!
# Found 514!
# Found 516!
# Found 517!
# Found 518!
# Found 519!
# Found 520!
# Found 521!
# Found 525!
# Found 527!
# Found 528!
# Found 529!
# Found 531!
# Found 532!
# Found 536!
# Found 537!
# Found 538!
# Found 539!
# Found 540!
# Found 541!
# Found 544!
# Found 545!
# Found 547!
# Found 548!
# Found 549!
# Found 550!
# Found 551!
# Found 553!
# Found 555!
# Found 557!
# Found 558!
# Found 559!
# Found 561!
# Found 563!
# Found 564!
# Found 565!
# Found 566!
# Found 567!
# Found 568!
# Found 569!
# Found 571!
# Found 572!
# Found 573!
# Found 576!
# Found 577!
# Found 580!
# Found 582!
# Found 583!
# Found 584!
# Found 585!
# Found 586!
# Found 587!
# Found 588!
# Found 590!
# Found 591!
# Found 592!
# Found 595!
# Found 596!
# Found 597!
# Found 598!
# Found 599!
# Found 601!
# Found 602!
# Found 604!
# Found 605!
# Found 607!
# Found 608!
# Found 610!
# Found 615!
# Found 616!
# Found 617!
# Found 618!
# Found 620!
# Found 621!
# Found 622!
# Found 624!
# Found 630!
# Found 631!
# Found 633!
# Found 634!
# Found 635!
# Found 636!
# Found 637!
# Found 638!
# Found 639!
# Found 640!
# Found 641!
# Found 642!
# Found 644!
# Found 645!
# Found 646!
# Found 647!
# Found 650!
# Found 652!
# Found 653!
# Found 654!
# Found 656!
# Found 657!
# Found 658!
# Found 660!
# Found 661!
# Found 662!
# Found 663!
# Found 664!
# Found 665!
# Found 667!
# Found 670!
# Found 672!
# Found 673!
# Found 676!
# Found 680!
# Found 685!
# Found 686!
# Found 687!
# Found 688!
# Found 689!
# Found 690!
# Found 691!
# Found 692!
# Found 693!
# Found 694!
# Found 695!
# Found 698!
# Found 699!
# Found 700!
# Found 701!
# Found 702!
# Found 703!
# Found 704!
# Found 706!
# Found 708!
# Found 710!
# Found 711!
# Found 713!
# Found 714!
# Found 716!
# Found 718!
# Found 720!
# Found 721!
# Found 722!
# Found 724!
# Found 725!
# Found 729!
# Found 730!
# Found 732!
# Found 733!
# Found 734!
# Found 736!
# Found 738!
# Found 741!
# Found 742!
# Found 743!
# Found 745!
# Found 746!
# Found 748!
# Found 749!
# Found 750!
# Found 751!
# Found 754!
# Found 755!
# Found 758!
# Found 761!
# Found 762!
# Found 763!
# Found 764!
# Found 767!
# Found 768!
# Found 769!
# Found 770!
# Found 772!
# Found 773!
# Found 774!
# Found 775!
# Found 776!
# Found 777!
# Found 779!
# Found 780!
# Found 781!
# Found 782!
# Found 784!
# Found 785!
# Found 786!
# Found 788!
# Found 794!
# Found 795!
# Found 797!
# Found 799!
# Found 800!
# Found 801!
# Found 802!
# Found 803!
# Found 804!
# Found 807!
# Found 808!
# Found 810!
# Found 811!
# Found 812!
# Found 813!
# Found 814!
# Found 817!
# Found 818!
# Found 819!
# Found 820!
# Found 822!
# Found 823!
# Found 827!
# Found 828!
# Found 829!
# Found 830!
# Found 831!
# Found 832!
# Found 835!
# Found 836!
# Found 837!
# Found 839!
# Found 840!
# Found 843!
# Found 847!
# Found 848!
# Found 853!
# Found 854!
# Found 855!
# Found 856!
# Found 857!
# Found 861!
# Found 862!
# Found 863!
# Found 864!
# Found 866!
# Found 867!
# Found 868!
# Found 870!
# Found 872!
# Found 873!
# Found 876!
# Found 877!
# Found 879!
# Found 880!
# Found 881!
# Found 882!
# Found 883!
# Found 884!
# Found 885!
# Found 886!
# Found 887!
# Found 890!
# Found 892!
# Found 894!
# Found 896!
# Found 899!
# Found 900!
# Found 901!
# Found 903!
# Found 905!
# Found 907!
# Found 910!
# Found 912!
# Found 913!
# Found 914!
# Found 916!
# Found 922!
# Found 923!
# Found 924!
# Found 925!
# Found 926!
# Found 928!
# Found 930!
# Found 931!
# Found 932!
# Found 933!
# Found 938!
# Found 949!
# Found 952!
# Found 953!
# Found 955!
# Found 957!
# Found 959!
# Found 962!
# Found 964!
# Found 965!
# Found 966!
# Found 968!
# Found 971!
# Found 973!
# Found 974!
# Found 975!
# Found 976!
# Found 977!
# Found 978!
# Found 979!
# Found 980!
# Found 981!
# Found 983!
# Found 986!
# Found 987!
# Found 988!
# Found 989!
# Found 990!
# Found 991!
# Found 992!
# Found 993!
# Found 999!

# %% [markdown]
# ### Now let's do it the Pythonic way
# Python has this nifty inclusion operator called ``in`` that we use all the time in our loops! Let's revisit our two previous examples using the ``in`` operator.

# %%
key = 516
key in random_values
# Out:
# True

# %%
for i in normal_values:
    if i in random_values:
        print("Found {}!".format(i))
# Out:
# Found 0!
# Found 1!
# Found 4!
# Found 5!
# Found 7!
# Found 10!
# Found 11!
# Found 13!
# Found 16!
# Found 18!
# Found 20!
# Found 21!
# Found 22!
# Found 23!
# Found 26!
# Found 27!
# Found 28!
# Found 29!
# Found 32!
# Found 33!
# Found 34!
# Found 35!
# Found 37!
# Found 38!
# Found 40!
# Found 41!
# Found 42!
# Found 43!
# Found 44!
# Found 45!
# Found 46!
# Found 48!
# Found 49!
# Found 50!
# Found 52!
# Found 53!
# Found 55!
# Found 56!
# Found 57!
# Found 59!
# Found 60!
# Found 64!
# Found 67!
# Found 69!
# Found 70!
# Found 71!
# Found 72!
# Found 73!
# Found 74!
# Found 75!
# Found 76!
# Found 81!
# Found 82!
# Found 85!
# Found 87!
# Found 88!
# Found 89!
# Found 93!
# Found 94!
# Found 95!
# Found 96!
# Found 98!
# Found 99!
# Found 102!
# Found 104!
# Found 106!
# Found 107!
# Found 108!
# Found 110!
# Found 112!
# Found 113!
# Found 114!
# Found 115!
# Found 116!
# Found 118!
# Found 122!
# Found 124!
# Found 125!
# Found 126!
# Found 128!
# Found 130!
# Found 132!
# Found 138!
# Found 139!
# Found 142!
# Found 143!
# Found 146!
# Found 147!
# Found 149!
# Found 150!
# Found 151!
# Found 152!
# Found 154!
# Found 155!
# Found 156!
# Found 158!
# Found 162!
# Found 163!
# Found 167!
# Found 168!
# Found 169!
# Found 170!
# Found 172!
# Found 173!
# Found 175!
# Found 177!
# Found 180!
# Found 181!
# Found 182!
# Found 183!
# Found 184!
# Found 185!
# Found 188!
# Found 189!
# Found 190!
# Found 191!
# Found 192!
# Found 194!
# Found 195!
# Found 198!
# Found 200!
# Found 202!
# Found 205!
# Found 207!
# Found 208!
# Found 209!
# Found 211!
# Found 212!
# Found 213!
# Found 216!
# Found 217!
# Found 218!
# Found 221!
# Found 222!
# Found 226!
# Found 228!
# Found 231!
# Found 232!
# Found 233!
# Found 234!
# Found 236!
# Found 239!
# Found 240!
# Found 241!
# Found 243!
# Found 244!
# Found 246!
# Found 249!
# Found 253!
# Found 254!
# Found 255!
# Found 256!
# Found 258!
# Found 259!
# Found 261!
# Found 262!
# Found 263!
# Found 264!
# Found 267!
# Found 268!
# Found 271!
# Found 273!
# Found 274!
# Found 275!
# Found 276!
# Found 277!
# Found 278!
# Found 279!
# Found 281!
# Found 283!
# Found 284!
# Found 285!
# Found 286!
# Found 287!
# Found 288!
# Found 289!
# Found 290!
# Found 294!
# Found 295!
# Found 297!
# Found 299!
# Found 301!
# Found 302!
# Found 303!
# Found 304!
# Found 311!
# Found 314!
# Found 317!
# Found 318!
# Found 319!
# Found 321!
# Found 322!
# Found 324!
# Found 325!
# Found 326!
# Found 327!
# Found 330!
# Found 334!
# Found 336!
# Found 338!
# Found 340!
# Found 341!
# Found 342!
# Found 343!
# Found 346!
# Found 348!
# Found 349!
# Found 350!
# Found 351!
# Found 353!
# Found 354!
# Found 356!
# Found 357!
# Found 359!
# Found 360!
# Found 361!
# Found 362!
# Found 363!
# Found 364!
# Found 365!
# Found 367!
# Found 369!
# Found 372!
# Found 373!
# Found 374!
# Found 375!
# Found 376!
# Found 377!
# Found 378!
# Found 381!
# Found 383!
# Found 384!
# Found 385!
# Found 386!
# Found 387!
# Found 389!
# Found 390!
# Found 391!
# Found 394!
# Found 395!
# Found 396!
# Found 397!
# Found 398!
# Found 400!
# Found 401!
# Found 402!
# Found 404!
# Found 406!
# Found 407!
# Found 409!
# Found 410!
# Found 411!
# Found 412!
# Found 414!
# Found 415!
# Found 416!
# Found 417!
# Found 419!
# Found 420!
# Found 421!
# Found 422!
# Found 423!
# Found 424!
# Found 425!
# Found 426!
# Found 427!
# Found 428!
# Found 430!
# Found 431!
# Found 432!
# Found 433!
# Found 434!
# Found 435!
# Found 436!
# Found 438!
# Found 439!
# Found 440!
# Found 442!
# Found 445!
# Found 446!
# Found 450!
# Found 451!
# Found 452!
# Found 453!
# Found 455!
# Found 456!
# Found 457!
# Found 458!
# Found 459!
# Found 460!
# Found 461!
# Found 462!
# Found 464!
# Found 465!
# Found 466!
# Found 468!
# Found 469!
# Found 471!
# Found 472!
# Found 474!
# Found 475!
# Found 476!
# Found 478!
# Found 479!
# Found 480!
# Found 484!
# Found 485!
# Found 486!
# Found 487!
# Found 489!
# Found 490!
# Found 491!
# Found 493!
# Found 496!
# Found 497!
# Found 498!
# Found 499!
# Found 501!
# Found 502!
# Found 503!
# Found 506!
# Found 507!
# Found 508!
# Found 509!
# Found 511!
# Found 513!
# Found 514!
# Found 516!
# Found 517!
# Found 518!
# Found 519!
# Found 520!
# Found 521!
# Found 525!
# Found 527!
# Found 528!
# Found 529!
# Found 531!
# Found 532!
# Found 536!
# Found 537!
# Found 538!
# Found 539!
# Found 540!
# Found 541!
# Found 544!
# Found 545!
# Found 547!
# Found 548!
# Found 549!
# Found 550!
# Found 551!
# Found 553!
# Found 555!
# Found 557!
# Found 558!
# Found 559!
# Found 561!
# Found 563!
# Found 564!
# Found 565!
# Found 566!
# Found 567!
# Found 568!
# Found 569!
# Found 571!
# Found 572!
# Found 573!
# Found 576!
# Found 577!
# Found 580!
# Found 582!
# Found 583!
# Found 584!
# Found 585!
# Found 586!
# Found 587!
# Found 588!
# Found 590!
# Found 591!
# Found 592!
# Found 595!
# Found 596!
# Found 597!
# Found 598!
# Found 599!
# Found 601!
# Found 602!
# Found 604!
# Found 605!
# Found 607!
# Found 608!
# Found 610!
# Found 615!
# Found 616!
# Found 617!
# Found 618!
# Found 620!
# Found 621!
# Found 622!
# Found 624!
# Found 630!
# Found 631!
# Found 633!
# Found 634!
# Found 635!
# Found 636!
# Found 637!
# Found 638!
# Found 639!
# Found 640!
# Found 641!
# Found 642!
# Found 644!
# Found 645!
# Found 646!
# Found 647!
# Found 650!
# Found 652!
# Found 653!
# Found 654!
# Found 656!
# Found 657!
# Found 658!
# Found 660!
# Found 661!
# Found 662!
# Found 663!
# Found 664!
# Found 665!
# Found 667!
# Found 670!
# Found 672!
# Found 673!
# Found 676!
# Found 680!
# Found 685!
# Found 686!
# Found 687!
# Found 688!
# Found 689!
# Found 690!
# Found 691!
# Found 692!
# Found 693!
# Found 694!
# Found 695!
# Found 698!
# Found 699!
# Found 700!
# Found 701!
# Found 702!
# Found 703!
# Found 704!
# Found 706!
# Found 708!
# Found 710!
# Found 711!
# Found 713!
# Found 714!
# Found 716!
# Found 718!
# Found 720!
# Found 721!
# Found 722!
# Found 724!
# Found 725!
# Found 729!
# Found 730!
# Found 732!
# Found 733!
# Found 734!
# Found 736!
# Found 738!
# Found 741!
# Found 742!
# Found 743!
# Found 745!
# Found 746!
# Found 748!
# Found 749!
# Found 750!
# Found 751!
# Found 754!
# Found 755!
# Found 758!
# Found 761!
# Found 762!
# Found 763!
# Found 764!
# Found 767!
# Found 768!
# Found 769!
# Found 770!
# Found 772!
# Found 773!
# Found 774!
# Found 775!
# Found 776!
# Found 777!
# Found 779!
# Found 780!
# Found 781!
# Found 782!
# Found 784!
# Found 785!
# Found 786!
# Found 788!
# Found 794!
# Found 795!
# Found 797!
# Found 799!
# Found 800!
# Found 801!
# Found 802!
# Found 803!
# Found 804!
# Found 807!
# Found 808!
# Found 810!
# Found 811!
# Found 812!
# Found 813!
# Found 814!
# Found 817!
# Found 818!
# Found 819!
# Found 820!
# Found 822!
# Found 823!
# Found 827!
# Found 828!
# Found 829!
# Found 830!
# Found 831!
# Found 832!
# Found 835!
# Found 836!
# Found 837!
# Found 839!
# Found 840!
# Found 843!
# Found 847!
# Found 848!
# Found 853!
# Found 854!
# Found 855!
# Found 856!
# Found 857!
# Found 861!
# Found 862!
# Found 863!
# Found 864!
# Found 866!
# Found 867!
# Found 868!
# Found 870!
# Found 872!
# Found 873!
# Found 876!
# Found 877!
# Found 879!
# Found 880!
# Found 881!
# Found 882!
# Found 883!
# Found 884!
# Found 885!
# Found 886!
# Found 887!
# Found 890!
# Found 892!
# Found 894!
# Found 896!
# Found 899!
# Found 900!
# Found 901!
# Found 903!
# Found 905!
# Found 907!
# Found 910!
# Found 912!
# Found 913!
# Found 914!
# Found 916!
# Found 922!
# Found 923!
# Found 924!
# Found 925!
# Found 926!
# Found 928!
# Found 930!
# Found 931!
# Found 932!
# Found 933!
# Found 938!
# Found 949!
# Found 952!
# Found 953!
# Found 955!
# Found 957!
# Found 959!
# Found 962!
# Found 964!
# Found 965!
# Found 966!
# Found 968!
# Found 971!
# Found 973!
# Found 974!
# Found 975!
# Found 976!
# Found 977!
# Found 978!
# Found 979!
# Found 980!
# Found 981!
# Found 983!
# Found 986!
# Found 987!
# Found 988!
# Found 989!
# Found 990!
# Found 991!
# Found 992!
# Found 993!
# Found 999!

# %% [markdown]
# ## Let's talk about binary search
# So linear search is cool and all, but what about something faster? Well, we can improve our searching if we *know* that our collection is in sorted order.
#
# Let's sort our ```random_values``` list:

# %%
sorted_values = sorted(random_values)

# %% [markdown]
# Now we can take advantage of our sorted values and say: compare my ```key``` against the middle value within my list. From there, we evaluate:
#
# **Is my ```key``` value greater than the list's value at the middle index? Is it less than? Equal to?**
#
# If our ```key``` is found, then we're done. For our purposes, let's say our key is *greater than* the value at the middle of the list. Since our list is sorted, we **know** we won't find it *below* the middle value. Therefore, we can eliminate *half of our search space* and only consider the upper half of our list when re-searching.
#
# <img src="bin_search.png">
#
# Let's implement binary search recursively:

# %%
def rec_binary_search(list_of_values, key):
    # if our list is empty, we can't find key
    if len(list_of_values) == 0:
        return "{} was not found".format(key)
    else:
        
        mid = len(list_of_values) // 2
        if key > list_of_values[mid]:
            return rec_binary_search(list_of_values[mid+1:], key)
        elif key < list_of_values[mid]:
            return rec_binary_search(list_of_values[:mid], key)
        else:
            return "{} was found".format(key)

# %% [markdown]
# Let's implement binary search iteratively:

# %%
def iter_binary_search(list_of_values, key):
    left_index = 0
    right_index = len(list_of_values) - 1
    
    while (left_index <= right_index):
        mid = (left_index + right_index) // 2
        if key > list_of_values[mid]:
            left_index = mid + 1
        elif key < list_of_values[mid]:
            right_index = mid - 1
        else:
            return "{} was found".format(key)
        
    return "{} was not found".format(key)

# %%
list_of_values = [17, 20, 26, 31, 44, 54, 55, 65, 77, 93]
for value in list_of_values:
    print(rec_binary_search(list_of_values, value))
    print(iter_binary_search(list_of_values, value))
# Out:
# 17 was found
# 17 was found
# 20 was found
# 20 was found
# 26 was found
# 26 was found
# 31 was found
# 31 was found
# 44 was found
# 44 was found
# 54 was found
# 54 was found
# 55 was found
# 55 was found
# 65 was found
# 65 was found
# 77 was found
# 77 was found
# 93 was found
# 93 was found

# %% [markdown]
# Cool! So we've that wraps up searching in Python. Next, we introduce sorting.

# %% [markdown]
# # Sorting
#
# Sorting is the (not-so) simple task of taking a collection of values/objects/etc. and arranging them in a cohesive, sorted order (ascending *or* descending). We all (hopefully) know the basic sorting methods, including selection, insertion, and bubble sorts.
#
# We'll introduce two more advanced sorting methods -- mergesort and quicksort -- that are much quicker than the previously mentioned sorting algorithms. Note that we won't be covering the **very advanced, objectively necessary** <a href="http://rosettacode.org/wiki/Sorting_algorithms/Sleep_sort">sleep sort</a> or <a href="https://en.wikipedia.org/wiki/Bogosort">bogo sort</a> algorithms (sleep sort sorts any list of numbers in O(n) time -- true story)*.
#
# With that, let's approach mergesort.
#
# \* I'm totally kidding.
#
#
# ## Mergesort
#
# Mergesort is a recursive sorting algorithm that recursively splits a list in half until it's dealing with a list of size 1. By definition, a list of size 0 or 1 is considered sorted. Ergo, if the list has a size of 2 or more, we recursively split it in half and invoke merge sort on both halves.
#
# A vital part of merge sort is the *merge* operation, which is done once each half is sorted. Merging is where we take two sorted sub-arrays and merge them into a single, sorted, list.
#
# Let's see if we can visualize it. Take our list:
#
#                         | 10 | 12 | 34 | 58 | 43 | 25 | 19 | 61 | 49 | 32 |
#
# We note that it's length is greater than 1, so (by our definition) it's unsorted. We first recursively break the problem into half by recursively calling mergesort on the first half of the list while the list's length is greater than 1. I've put an asterisk * next to the arrays that are considered sorted. Ergo:
#
#                         | 10 | 12 | 34 | 58 | 43 | 25 | 19 | 61 | 49 | 32 |
#                                    /                           \
#             | 10 | 12 | 34 | 58 | 43 |                       | 25 | 19 | 61 | 49 | 32 |
#                      /      \                                         /      \
#           | 10 | 12 |        | 34 | 58 | 43 |              | 25 | 19 |        | 61 | 49 | 32 |
#               / \                /      \                      / \                /      \
#         | 10*|   | 12*|    | 34*|        | 58 | 43 |     | 25*|    | 19*|   | 61*|        | 49 | 32 |
#                                              / \                                              / \
#                                        | 58*|   | 43*|                                  | 49*|    | 32*|

# %% [markdown]
# ## Feel free to check out any of the following links for more resources on Python:
# <a href="http://interactivepython.org/runestone/static/pythonds/index.html">Interactive Python</a>: A great open source repository for interactive textbooks, including one on problem solving in Python. <br>
# <a href="http://www.amazon.com/Python-Cookbook-Alex-Martelli/dp/0596007973/">Python Cookbook</a>: Good collection of problems to solve and projects to undertake using Python <br>
# <a href="http://flask.pocoo.org/docs/0.10/">Flask</a>: A microframework for Python web development. <br>
#
# <a href="http://nbviewer.ipython.org/">nbviewer</a>
#
# # Thanks!
